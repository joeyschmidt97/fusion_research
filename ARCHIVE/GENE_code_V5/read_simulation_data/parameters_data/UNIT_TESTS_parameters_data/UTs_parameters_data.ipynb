# %%
import os
os.chdir("..")
from GP_parameters_data_V4 import parameters_filepath_to_dict, species_list

# %% [markdown]
# # Filepspec_listth is directory or does not exist

# %%
test_dir = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

filepath = os.path.join(test_dir, 'TEST_3spec_k1')
parameters_dict = parameters_filepath_to_dict(filepath)

parameters_path = os.path.join(filepath, 'parameters_1001')
parameters_dict = parameters_filepath_to_dict(parameters_path)
# Out:
# The file path does not exist or is not a file: /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/TEST_3spec_k1
# The file path does not exist or is not a file: /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/TEST_3spec_k1/parameters_1001

# %%
omega_path = os.path.join(filepath, 'omega.dat')
parameters_dict = parameters_filepath_to_dict(omega_path)
# Out:
# The filename does not start with 'parameters': /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/TEST_3spec_k1/omega.dat

# %% [markdown]
# # parameters.dat checks

# %%
filepath = os.path.join(test_dir, 'TEST_3spec_k1')
parameters_path = os.path.join(filepath, 'parameters.dat')
parameters_dict = parameters_filepath_to_dict(parameters_path)

assert isinstance(parameters_dict['nz0'],int)
assert isinstance(parameters_dict['n_spec'],int)
assert isinstance(parameters_dict['kymin'],float)

parameters_dict['key_list']
# Out:
# ['n_procs_s',
#  'n_procs_v',
#  'n_procs_w',
#  'n_procs_x',
#  'n_procs_y',
#  'n_procs_z',
#  'n_procs_sim',
#  'n_spec',
#  'nx0',
#  'nky0',
#  'nz0',
#  'nv0',
#  'nw0',
#  'kymin',
#  'lv',
#  'lw',
#  'adapt_lx',
#  'x0',
#  'n0_global',
#  'ky0_ind',
#  'diagdir',
#  'read_checkpoint',
#  'write_checkpoint',
#  'istep_field',
#  'istep_mom',
#  'istep_nrg',
#  'istep_omega',
#  'istep_vsp',
#  'istep_schpt',
#  'istep_energy',
#  'istep_energy3d',
#  'write_std',
#  'iterdb_file',
#  'nonlinear',
#  'comp_type',
#  'perf_vec',
#  'nblocks',
#  'arakawa_zv',
#  'timescheme',
#  'dt_max',
#  'dt_vlasov',
#  'ev_coll',
#  'timelim',
#  'ntimesteps',
#  'beta',
#  'debye2',
#  'bpar',
#  'collision_op',
#  'coll',
#  'coll_cons_model',
#  'init_cond',
#  'hyp_z_with_dz_prefactor',
#  'hyp_z',
#  'hyp_v_with_dv_prefactor',
#  'hyp_v',
#  'perf_tsteps',
#  'magn_geometry',
#  'q0',
#  'shat',
#  'geomfile',
#  'edge_opt',
#  'minor_r',
#  'major_R',
#  'rhostar',
#  'dpdx_term',
#  'dpdx_pm',
#  'norm_flux_projection',
#  'name1',
#  'omn1',
#  'omt1',
#  'mass1',
#  'temp1',
#  'dens1',
#  'charge1',
#  'name2',
#  'omn2',
#  'omt2',
#  'mass2',
#  'temp2',
#  'dens2',
#  'charge2',
#  'name3',
#  'omn3',
#  'omt3',
#  'mass3',
#  'temp3',
#  'dens3',
#  'charge3',
#  'number of computed time steps',
#  'time for initial value solver',
#  'calc_dt',
#  'nltdt_off',
#  'ev_coll_est',
#  'init_time',
#  'n_fields',
#  'n_moms',
#  'nrgcols',
#  'lx',
#  'ly',
#  'PRECISION',
#  'ENDIANNESS',
#  'OMP_NUM_THREADS',
#  'GIT_BRANCH',
#  'RELEASE',
#  'nu_ei',
#  'nustar_i',
#  'nustar_e',
#  'Bref',
#  'Tref',
#  'nref',
#  'Lref',
#  'mref',
#  'is_bsg',
#  'filepath']

# %% [markdown]
# # parameters_0002 checks

# %%
filepath = os.path.join(test_dir, 'scanfiles0004')
parameters_path = os.path.join(filepath, 'parameters_0002')
parameters_dict = parameters_filepath_to_dict(parameters_path)

assert isinstance(parameters_dict['nz0'],int)
assert isinstance(parameters_dict['n_spec'],int)
assert isinstance(parameters_dict['kymin'],float)

print(parameters_dict['filepath'])

parameters_dict
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0004/parameters_0002
# OrderedDict([('n_procs_s', 1),
#              ('n_procs_v', 2),
#              ('n_procs_w', 4),
#              ('n_procs_x', 1),
#              ('n_procs_y', 1),
#              ('n_procs_z', 32),
#              ('n_procs_sim', 256),
#              ('n_parallel_sims', 5),
#              ('n_spec', 3),
#              ('nx0', 7),
#              ('nky0', 1),
#              ('nz0', 256),
#              ('nv0', 36),
#              ('nw0', 8),
#              ('kymin', 0.3),
#              ('lv', 3.0),
#              ('lw', 9.0),
#              ('adapt_lx', True),
#              ('x0', 0.9),
#              ('n0_global', 7),
#              ('ky0_ind', 1),
#              ('diagdir',
#               "'/global/cscratch1/sd/joeschm/ST_research/ETG_research/129015/scanfiles0004/'"),
#              ('read_checkpoint', False),
#              ('write_checkpoint', True),
#              ('istep_field', 100),
#              ('istep_mom', 100),
#              ('istep_nrg', 20),
#              ('istep_omega', 20),
#              ('istep_vsp', 5000),
#              ('istep_schpt', 10000),
#              ('istep_energy', 100),
#              ('istep_energy3d', 300),
#              ('write_std', True),
#              ('iterdb_file',
#               "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"),
#              ('nonlinear', False),
#              ('comp_type', "'IV'"),
#              ('perf_vec', '1 2 2 3 1 2 2 2 2'),
#              ('nblocks', 6),
#              ('arakawa_zv', False),
#              ('timescheme', "'RK4'"),
#              ('dt_max', 0.000391),
#              ('dt_vlasov', 0.000422),
#              ('ev_coll', 5058.7),
#              ('timelim', 8600000),
#              ('ntimesteps', 20000000),
#              ('beta', 0.013169132),
#              ('debye2', 1.4077055e-05),
#              ('bpar', True),
#              ('collision_op', "'landau'"),
#              ('coll', 0.04200756),
#              ('coll_cons_model', "'xu_rosenbluth'"),
#              ('init_cond', "'alm'"),
#              ('hyp_z_with_dz_prefactor', False),
#              ('hyp_z', -2.0),
#              ('hyp_v_with_dv_prefactor', False),
#              ('hyp_v', 0.2),
#              ('perf_tsteps', -1),
#              ('magn_geometry', "'tracer_efit'"),
#              ('q0', 8.8631487),
#              ('shat', 2.979017),
#              ('geomfile', "'g129015.00409_450'"),
#              ('edge_opt', 8.0),
#              ('minor_r', 1.0),
#              ('major_R', 1.0208728),
#              ('rhostar', 0.0042325432),
#              ('dpdx_term', "'full_drift'"),
#              ('dpdx_pm', 0.19617095),
#              ('norm_flux_projection', False),
#              ('name1', "'i'"),
#              ('omn1', 2.1733975),
#              ('omt1', 1.8083051),
#              ('mass1', 1.0),
#              ('temp1', 0.7495389),
#              ('dens1', 0.79665666),
#              ('charge1', 1.0),
#              ('name2', "'e'"),
#              ('omn2', 2.6446951),
#              ('omt2', 9.1720599),
#              ('mass2', 0.0002724),
#              ('temp2', 1.0),
#              ('dens2', 1.0),
#              ('charge2', -1.0),
#              ('name3', "'c'"),
#              ('omn3', 4.4911402),
#              ('omt3', 1.8083051),
#              ('mass3', 6.0),
#              ('temp3', 0.7495389),
#              ('dens3', 0.033890556),
#              ('charge3', 6.0),
#              ('step_time', 0.0158),
#              ('number of computed time steps', 405439),
#              ('time for initial value solver', 6417.109),
#              ('calc_dt', True),
#              ('nltdt_off', False),
#              ('ev_coll_est', 4174.4997),
#              ('init_time', 6.7158),
#              ('n_fields', 3),
#              ('n_moms', 9),
#              ('nrgcols', 10),
#              ('lx', 1.11894),
#              ('ly', 20.944),
#              ('PRECISION', 'DOUBLE'),
#              ('ENDIANNESS', 'LITTLE'),
#              ('OMP_NUM_THREADS', 1),
#              ('GIT_BRANCH',
#               '8249e6287156f466bd64c2a72216c36064b46eac                    '),
#              ('RELEASE', '2.0 - patch 1'),
#              ('nu_ei', 20.531883),
#              ('nustar_i', 3.507084),
#              ('nustar_e', 2.786439),
#              ('Bref', 0.48496260233783195),
#              ('Tref', 0.17379721292233993),
#              ('nref', 4.4220720166996035),
#              ('Lref', 0.9264538784967838),
#              ('mref', 2.0),
#              ('is_bsg', False),
#              ('filepath',
#               '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0004/parameters_0002'),
#              ('key_list',
#               ['n_procs_s',
#                'n_procs_v',
#                'n_procs_w',
#                'n_procs_x',
#                'n_procs_y',
#                'n_procs_z',
#                'n_procs_sim',
#                'n_parallel_sims',
#                'n_spec',
#                'nx0',
#                'nky0',
#                'nz0',
#                'nv0',
#                'nw0',
#                'kymin',
#                'lv',
#                'lw',
#                'adapt_lx',
#                'x0',
#                'n0_global',
#                'ky0_ind',
#                'diagdir',
#                'read_checkpoint',
#                'write_checkpoint',
#                'istep_field',
#                'istep_mom',
#                'istep_nrg',
#                'istep_omega',
#                'istep_vsp',
#                'istep_schpt',
#                'istep_energy',
#                'istep_energy3d',
#                'write_std',
#                'iterdb_file',
#                'nonlinear',
#                'comp_type',
#                'perf_vec',
#                'nblocks',
#                'arakawa_zv',
#                'timescheme',
#                'dt_max',
#                'dt_vlasov',
#                'ev_coll',
#                'timelim',
#                'ntimesteps',
#                'beta',
#                'debye2',
#                'bpar',
#                'collision_op',
#                'coll',
#                'coll_cons_model',
#                'init_cond',
#                'hyp_z_with_dz_prefactor',
#                'hyp_z',
#                'hyp_v_with_dv_prefactor',
#                'hyp_v',
#                'perf_tsteps',
#                'magn_geometry',
#                'q0',
#                'shat',
#                'geomfile',
#                'edge_opt',
#                'minor_r',
#                'major_R',
#                'rhostar',
#                'dpdx_term',
#                'dpdx_pm',
#                'norm_flux_projection',
#                'name1',
#                'omn1',
#                'omt1',
#                'mass1',
#                'temp1',
#                'dens1',
#                'charge1',
#                'name2',
#                'omn2',
#                'omt2',
#                'mass2',
#                'temp2',
#                'dens2',
#                'charge2',
#                'name3',
#                'omn3',
#                'omt3',
#                'mass3',
#                'temp3',
#                'dens3',
#                'charge3',
#                'step_time',
#                'number of computed time steps',
#                'time for initial value solver',
#                'calc_dt',
#                'nltdt_off',
#                'ev_coll_est',
#                'init_time',
#                'n_fields',
#                'n_moms',
#                'nrgcols',
#                'lx',
#                'ly',
#                'PRECISION',
#                'ENDIANNESS',
#                'OMP_NUM_THREADS',
#                'GIT_BRANCH',
#                'RELEASE',
#                'nu_ei',
#                'nustar_i',
#                'nustar_e',
#                'Bref',
#                'Tref',
#                'nref',
#                'Lref',
#                'mref',
#                'is_bsg',
#                'filepath'])])

# %% [markdown]
# # Species list

# %%
spec_list = species_list(parameters_path)

print(spec_list)
print(spec_list[0])
print(type(spec_list))
# Out:
# (('i', 1), ('e', 2), ('c', 3))
# ('i', 1)
# <class 'tuple'>

# %%
filepath = os.path.join(test_dir, 'scanfiles0004')
parameters_path = os.path.join(filepath, 'parameters_0002')
parameters_dict = parameters_filepath_to_dict(parameters_path)

print(len(parameters_dict['key_list']))
print(parameters_dict['key_list'])
# Out:
# 116
# ['n_procs_s', 'n_procs_v', 'n_procs_w', 'n_procs_x', 'n_procs_y', 'n_procs_z', 'n_procs_sim', 'n_parallel_sims', 'n_spec', 'nx0', 'nky0', 'nz0', 'nv0', 'nw0', 'kymin', 'lv', 'lw', 'adapt_lx', 'x0', 'n0_global', 'ky0_ind', 'diagdir', 'read_checkpoint', 'write_checkpoint', 'istep_field', 'istep_mom', 'istep_nrg', 'istep_omega', 'istep_vsp', 'istep_schpt', 'istep_energy', 'istep_energy3d', 'write_std', 'iterdb_file', 'nonlinear', 'comp_type', 'perf_vec', 'nblocks', 'arakawa_zv', 'timescheme', 'dt_max', 'dt_vlasov', 'ev_coll', 'timelim', 'ntimesteps', 'beta', 'debye2', 'bpar', 'collision_op', 'coll', 'coll_cons_model', 'init_cond', 'hyp_z_with_dz_prefactor', 'hyp_z', 'hyp_v_with_dv_prefactor', 'hyp_v', 'perf_tsteps', 'magn_geometry', 'q0', 'shat', 'geomfile', 'edge_opt', 'minor_r', 'major_R', 'rhostar', 'dpdx_term', 'dpdx_pm', 'norm_flux_projection', 'name1', 'omn1', 'omt1', 'mass1', 'temp1', 'dens1', 'charge1', 'name2', 'omn2', 'omt2', 'mass2', 'temp2', 'dens2', 'charge2', 'name3', 'omn3', 'omt3', 'mass3', 'temp3', 'dens3', 'charge3', 'step_time', 'number of computed time steps', 'time for initial value solver', 'calc_dt', 'nltdt_off', 'ev_coll_est', 'init_time', 'n_fields', 'n_moms', 'nrgcols', 'lx', 'ly', 'PRECISION', 'ENDIANNESS', 'OMP_NUM_THREADS', 'GIT_BRANCH', 'RELEASE', 'nu_ei', 'nustar_i', 'nustar_e', 'Bref', 'Tref', 'nref', 'Lref', 'mref', 'is_bsg', 'filepath']
