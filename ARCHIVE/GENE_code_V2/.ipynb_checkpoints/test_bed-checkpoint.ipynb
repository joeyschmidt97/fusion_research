# %%
import os
import sys
sys.path.insert(1, '/global/u1/j/joeschm/fusion_research/GENE_code_V3')
from GP_simulation_data_V3 import filepath_to_simulation_dict_list
from GP_parameter_data_V3 import filepath_to_parameter_dict_list, parameter_filepath_to_dict
from GP_omega_data_V3 import omega_filepath_to_dict
from GP_nrg_data_V3 import nrg_filepath_to_dict

# from GP_criteria_functions_V3 import criteria_parser

# %%
filepath_list = ['/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000',
                 '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit']

# filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

# criteria_list = ['gamma(cs/a)<100', 'omega==2', 'kymin < 20']
criteria_list = ['kymin <= 1', 'gamma']

simulation_dict_list = filepath_to_simulation_dict_list(filepath_list, criteria_list=criteria_list, load_files = ['omega'])

for simulation_dict in simulation_dict_list:
    # print(simulation_dict['parameters_dict'])
    keys = simulation_dict.keys()
# Out:
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0001 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.3175008), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.607642), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.3175008), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 283819), ('time for initial value solver', 1201.447), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 2.1221), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0001'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0001')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.019, 'omega': -0.15, 'filename': 'omega_0001', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0001'}
# gamma = 0.019
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0002 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.4394745), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.6922547), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.4394745), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 314219), ('time for initial value solver', 1335.56), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 2.3164), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0002'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0002')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.02, 'omega': -0.157, 'filename': 'omega_0002', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0002'}
# gamma = 0.02
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0003 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.5614482), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.7768674), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.5614482), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 352739), ('time for initial value solver', 1480.495), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 2.5338), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0003'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0003')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.021, 'omega': -0.165, 'filename': 'omega_0003', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0003'}
# gamma = 0.021
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0004 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3538.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.028365177), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.3175008), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.607642), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.3175008), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 327059), ('time for initial value solver', 1386.381), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3044.0551), ('init_time', 2.5518), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 14.422077), ('nustar_i', 2.74245), ('nustar_e', 1.713321), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0004'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0004')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.018, 'omega': -0.15, 'filename': 'omega_0004', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0004'}
# gamma = 0.018
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0005 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3538.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.028365177), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.4394745), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.6922547), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.4394745), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 368439), ('time for initial value solver', 1553.953), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3044.0551), ('init_time', 2.6089), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 14.422077), ('nustar_i', 2.74245), ('nustar_e', 1.713321), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0005'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0005')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.019, 'omega': -0.158, 'filename': 'omega_0005', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0005'}
# gamma = 0.019
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0006 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3538.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.028365177), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.5614482), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.7768674), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.5614482), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 423579), ('time for initial value solver', 1779.747), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3044.0551), ('init_time', 2.6087), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 14.422077), ('nustar_i', 2.74245), ('nustar_e', 1.713321), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0006'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0006')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.02, 'omega': -0.165, 'filename': 'omega_0006', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0006'}
# gamma = 0.02
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0007 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3715.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.029783436), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.3175008), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.607642), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.3175008), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 380279), ('time for initial value solver', 1617.387), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3196.2579), ('init_time', 2.5927), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 15.14318), ('nustar_i', 2.879573), ('nustar_e', 1.798987), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0007'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0007')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.018, 'omega': -0.151, 'filename': 'omega_0007', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0007'}
# gamma = 0.018
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0008 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3715.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.029783436), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.4394745), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.6922547), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.4394745), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 437839), ('time for initial value solver', 1855.142), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3196.2579), ('init_time', 2.5496), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 15.14318), ('nustar_i', 2.879573), ('nustar_e', 1.798987), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0008'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0008')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.018, 'omega': -0.158, 'filename': 'omega_0008', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0008'}
# gamma = 0.018
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0009 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3715.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.016349933), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.029783436), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.5614482), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.7768674), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.5614482), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 519799), ('time for initial value solver', 2211.39), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3196.2579), ('init_time', 2.4965), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 15.14318), ('nustar_i', 2.879573), ('nustar_e', 1.798987), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0009'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0009')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.019, 'omega': -0.166, 'filename': 'omega_0009', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0009'}
# gamma = 0.019
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0010 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.017210456), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.3175008), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.607642), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.3175008), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 318779), ('time for initial value solver', 1357.874), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 1.747), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0010'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0010')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.019, 'omega': -0.15, 'filename': 'omega_0010', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0010'}
# gamma = 0.019
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0011 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.017210456), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.4394745), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.6922547), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.4394745), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 358139), ('time for initial value solver', 1533.167), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 1.664), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0011'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0011')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.02, 'omega': -0.157, 'filename': 'omega_0011', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0011'}
# gamma = 0.02
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0012 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3362.0), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.017210456), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.026946918), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.5614482), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.7768674), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.5614482), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0043), ('number of computed time steps', 408699), ('time for initial value solver', 1745.997), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 2891.8524), ('init_time', 1.742), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 13.700973), ('nustar_i', 2.605328), ('nustar_e', 1.627655), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0012'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0012')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.021, 'omega': -0.165, 'filename': 'omega_0012', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0012'}
# gamma = 0.021
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0013 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 0.1), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 3), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000748), ('dt_vlasov', 0.000748), ('ev_coll', 3538.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.017210456), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.028365177), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.3175008), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.607642), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.3175008), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0042), ('number of computed time steps', 370619), ('time for initial value solver', 1564.138), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3044.0551), ('init_time', 1.6707), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 2.50814), ('ly', 62.8319), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 14.422077), ('nustar_i', 2.74245), ('nustar_e', 1.713321), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0013'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000'), ('suffix', '0013')])
# kymin = 0.1
# [True, False]
# --------------------
# gamma<20 {'kymin': 0.1, 'gamma': 0.019, 'omega': -0.15, 'filename': 'omega_0013', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', 'suffix': '0013'}
# gamma = 0.019
# [0, True]
# --------------------
# [True, True]
# True
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000 0014 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# ...
# kymin = 2.0
# [False, False]
# --------------------
# kymin<=1 {'kymin': 2.0, 'gamma': 1.134, 'omega': -3.439, 'filename': 'omega_0026', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000', 'suffix': '0026'}
# kymin = 2.0
# gamma<20 {'kymin': 2.0, 'gamma': 1.134, 'omega': -3.439, 'filename': 'omega_0026', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000', 'suffix': '0026', '__builtins__': {'__name__': 'builtins', '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fcdd4b178b0>>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'Exception': <class 'Exception'>, 'TypeError': <class 'TypeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'GeneratorExit': <class 'GeneratorExit'>, 'SystemExit': <class 'SystemExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'ImportError': <class 'ImportError'>, 'ModuleNotFoundError': <class 'ModuleNotFoundError'>, 'OSError': <class 'OSError'>, 'EnvironmentError': <class 'OSError'>, 'IOError': <class 'OSError'>, 'EOFError': <class 'EOFError'>, 'RuntimeError': <class 'RuntimeError'>, 'RecursionError': <class 'RecursionError'>, 'NotImplementedError': <class 'NotImplementedError'>, 'NameError': <class 'NameError'>, 'UnboundLocalError': <class 'UnboundLocalError'>, 'AttributeError': <class 'AttributeError'>, 'SyntaxError': <class 'SyntaxError'>, 'IndentationError': <class 'IndentationError'>, 'TabError': <class 'TabError'>, 'LookupError': <class 'L ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., 'execfile': <function execfile at 0x7fcdd4e5ddc0>, 'runfile': <function runfile at 0x7fcdd4d1da60>, '__IPYTHON__': True, 'display': <function display at 0x7fcdd64794c0>, '__pybind11_internals_v4_gcc_libstdcpp_cxxabi1016__': <capsule object NULL at 0x7fcd9b756b40>, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fcdd4aace80>>}}
# gamma = 1.134
# [False, True]
# --------------------
# [False, True]
# False
# ////////////////////
# [{'variable_key': 'kymin', 'criteria': 'kymin<=1', 'units': None}, {'variable_key': 'gamma', 'criteria': 'gamma<20', 'units': None}]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000 0027 dict_keys(['filepath', 'suffix', 'parameters_dict', 'omega_dict'])
# kymin<=1 OrderedDict([('n_procs_s', 1), ('n_procs_v', 2), ('n_procs_w', 4), ('n_procs_x', 1), ('n_procs_y', 1), ('n_procs_z', 32), ('n_procs_sim', 256), ('n_parallel_sims', 9), ('n_spec', 3), ('nx0', 7), ('nky0', 1), ('nz0', 128), ('nv0', 36), ('nw0', 8), ('kymin', 2.0), ('lv', 3.0), ('lw', 9.0), ('adapt_lx', True), ('x0', 0.8500264), ('n0_global', 50), ('ky0_ind', 1), ('diagdir', "'/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000/'"), ('read_checkpoint', False), ('write_checkpoint', True), ('istep_field', 100), ('istep_mom', 600), ('istep_nrg', 50), ('istep_omega', 20), ('istep_vsp', 5000), ('istep_schpt', 5000), ('istep_energy', 100), ('write_std', True), ('iterdb_file', "'/global/u1/j/joeschm/st_research/NSTXU_discharges/129015/NSTXU129015_g00409_450_p00400_x8099.iterdb'"), ('nonlinear', False), ('comp_type', "'IV'"), ('perf_vec', '1 2 2 3 1 2 2 2 2'), ('nblocks', 6), ('arakawa_zv', False), ('timescheme', "'RK4'"), ('dt_max', 0.000287), ('dt_vlasov', 0.000287), ('ev_coll', 3715.9), ('timelim', 8600000), ('ntimesteps', 20000000), ('beta', 0.018070979), ('debye2', 1.3491093e-05), ('bpar', True), ('collision_op', "'landau'"), ('coll', 0.029783436), ('coll_cons_model', "'xu_rosenbluth'"), ('init_cond', "'alm'"), ('hyp_z_with_dz_prefactor', False), ('hyp_z', -2.0), ('hyp_v_with_dv_prefactor', False), ('hyp_v', 0.2), ('perf_tsteps', -1), ('magn_geometry', "'tracer_efit'"), ('q0', 7.1213618), ('shat', 3.9870173), ('geomfile', "'g129015.00409_450'"), ('edge_opt', 8.0), ('minor_r', 1.0), ('major_R', 1.0208728), ('rhostar', 0.0047368176), ('dpdx_term', "'full_drift'"), ('dpdx_pm', 0.048974139), ('norm_flux_projection', False), ('name1', "'i'"), ('omn1', -0.21582844), ('omt1', 2.5614482), ('mass1', 1.0), ('temp1', 0.66464916), ('dens1', 0.78041896), ('charge1', 1.0), ('name2', "'e'"), ('omn2', 0.096374717), ('omt2', 1.7768674), ('mass2', 0.0002724), ('temp2', 1.0), ('dens2', 1.0), ('charge2', -1.0), ('name3', "'c'"), ('omn3', 1.2059845), ('omt3', 2.5614482), ('mass3', 6.0), ('temp3', 0.66464916), ('dens3', 0.03659684), ('charge3', 6.0), ('step_time', 0.0034), ('number of computed time steps', 38159), ('time for initial value solver', 129.116), ('calc_dt', True), ('nltdt_off', False), ('ev_coll_est', 3196.2579), ('init_time', 1.6726), ('n_fields', 3), ('n_moms', 9), ('nrgcols', 10), ('lx', 0.125407), ('ly', 3.14159), ('PRECISION', 'DOUBLE'), ('ENDIANNESS', 'LITTLE'), ('OMP_NUM_THREADS', 1), ('GIT_BRANCH', '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '), ('RELEASE', '2.0 - patch 4'), ('nu_ei', 15.14318), ('nustar_i', 2.879573), ('nustar_e', 1.798987), ('Bref', 0.48496260233783195), ('Tref', 0.21767740000000002), ('nref', 4.6141369999999995), ('Lref', 0.9264538784967837), ('mref', 2.0), ('is_bsg', False), ('filename', 'parameters_0027'), ('filepath', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000'), ('suffix', '0027')])
# kymin = 2.0
# [False, False]
# --------------------
# kymin<=1 {'kymin': 2.0, 'gamma': 1.225, 'omega': -3.522, 'filename': 'omega_0027', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000', 'suffix': '0027'}
# kymin = 2.0
# gamma<20 {'kymin': 2.0, 'gamma': 1.225, 'omega': -3.522, 'filename': 'omega_0027', 'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_2/scanfiles0000', 'suffix': '0027', '__builtins__': {'__name__': 'builtins', '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fcdd4b178b0>>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'Exception': <class 'Exception'>, 'TypeError': <class 'TypeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'GeneratorExit': <class 'GeneratorExit'>, 'SystemExit': <class 'SystemExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'ImportError': <class 'ImportError'>, 'ModuleNotFoundError': <class 'ModuleNotFoundError'>, 'OSError': <class 'OSError'>, 'EnvironmentError': <class 'OSError'>, 'IOError': <class 'OSError'>, 'EOFError': <class 'EOFError'>, 'RuntimeError': <class 'RuntimeError'>, 'RecursionError': <class 'RecursionError'>, 'NotImplementedError': <class 'NotImplementedError'>, 'NameError': <class 'NameError'>, 'UnboundLocalError': <class 'UnboundLocalError'>, 'AttributeError': <class 'AttributeError'>, 'SyntaxError': <class 'SyntaxError'>, 'IndentationError': <class 'IndentationError'>, 'TabError': <class 'TabError'>, 'LookupError': <class 'L ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., 'execfile': <function execfile at 0x7fcdd4e5ddc0>, 'runfile': <function runfile at 0x7fcdd4d1da60>, '__IPYTHON__': True, 'display': <function display at 0x7fcdd64794c0>, '__pybind11_internals_v4_gcc_libstdcpp_cxxabi1016__': <capsule object NULL at 0x7fcd9b756b40>, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fcdd4aace80>>}}
# gamma = 1.225
# [False, True]
# --------------------
# [False, True]
# False
# ////////////////////
# ['/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000', '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit']
# Total run time 0.8297724723815918 s

# %%
# # filepath_list = ['/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit',
# #                 '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.7/scanfiles0000',
# #                 '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0001']

# # filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan/scanfiles0001'
# # filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan/scanfiles0000'
# # filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/Non_linear_scans/ETG_scans_V4_base/parameters.dat'
# # filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/Non_linear_scans/ETG_scans_V4_base'

# # filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/MTM_limit/kymin_0.1'
# filepath_list = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'
# # criteria_list = ['kymin > 5', 'beta', 'coll', 'omt1', 'omt2', 'omt3', 'Bref', 'Tref', 'nref', 'Lref', 'mref']
# # criteria_list = 'kymin'
