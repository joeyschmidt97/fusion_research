# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/fusion_research/GENE_code')

from PRE_plot_PE_NE_OM_points import multiplot_PE_NE_OM

# %%
#Filepath for 129015
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129015/'
point_list = [.87, .85, .936]

multiplot_PE_NE_OM(path_discharge, point_list)

# %%
#Filepath for 129038
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129038/'
point_list = [.5, .655, .91]

multiplot_PE_NE_OM(path_discharge, point_list)

# %%
#Filepath for 132543
path_discharge = '/global/u1/j/joeschm/st_research/NSTXU_discharges/132543/'
point_list = [.83, .88, .916]

multiplot_PE_NE_OM(path_discharge, point_list)

# %%
#Filepath for 132588
path_discharge = '/global/u1/j/joeschm/st_research/NSTXU_discharges/132588/'
point_list = [.5, .48, .797]

multiplot_PE_NE_OM(path_discharge, point_list)
