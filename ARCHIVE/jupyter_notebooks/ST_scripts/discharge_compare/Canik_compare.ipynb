# %%
import numpy as np

import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github')

from terminal_omega_print import print_omega_data

# %% [markdown]
# # 129015

# %%
#129015: [PE, NE, OM] = [.87, .85, .936]

# %%
PE_NE_OM = [.87, .85, .936]
canik_PE_NE_OM = [i**2 for i in PE_NE_OM]

print(canik_PE_NE_OM)
# Out:
# [0.7569, 0.7224999999999999, 0.8760960000000001]

# %%
D_e_OM = 0.1346
chi_e_OM = 1.1

D_chi = D_e_OM/chi_e_OM
print('D/chi at 129015 OM:',D_chi)
# Out:
# D/chi at 129015 OM: 0.12236363636363635

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top'

criteria_list = []
scanfile_outputs = ['nz0', 'kymin', 'omn1', 'omn2', 'omn3', 'x0']

print_omega_data(filepath, scanfile_outputs, criteria_list)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# current directory: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad: 11.600863
# electron dens grad: 12.10412
# carbon dens grad: 14.260839
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad (30 perc +): 15.081121900000001
# electron dens grad (30 perc +): 15.735356000000001
# carbon dens grad (30 perc +): 18.539090700000003
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad (30 perc -): 8.1206041
# electron dens grad (30 perc -): 8.472883999999999
# carbon dens grad (30 perc -): 9.9825873
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# omega runs
#          scanfile suffix  kymin      omn2        x0  n0_global  Gamma_ES/Q_ES  \
# 1   scanfiles0001   0001    0.1  12.10412  0.936008          3       0.391927
# ...

# %% [markdown]
# # 129038

# %%
#129038: [PE, NE, OM] = [.5, .655, .91]

# %%
PE_NE_OM = [.5, .655, .91]
canik_PE_NE_OM = [i**2 for i in PE_NE_OM]

print(canik_PE_NE_OM)
# Out:
# [0.25, 0.42902500000000005, 0.8281000000000001]

# %%
D_e_OM = 0.161538
chi_e_OM = 1

D_chi = D_e_OM/chi_e_OM
print('D/chi at 129038 OM:',D_chi)
# Out:
# D/chi at 129038 OM: 0.161538

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top'

criteria_list = []
scanfile_outputs = ['nz0', 'kymin', 'omn1', 'omn2', 'omn3', 'x0']

print_omega_data(filepath, scanfile_outputs, criteria_list)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# current directory: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad: 7.3145976
# electron dens grad: 7.3153377
# carbon dens grad: 7.3160307
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad (30 perc +): 9.50897688
# electron dens grad (30 perc +): 9.50993901
# carbon dens grad (30 perc +): 9.51083991
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ion dens grad (30 perc -): 5.120218319999999
# electron dens grad (30 perc -): 5.120736389999999
# carbon dens grad (30 perc -): 5.12122149
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# omega runs
#          scanfile suffix  kymin      omn2       x0  n0_global  Gamma_ES/Q_ES  \
# 25  scanfiles0013   0001    0.1  7.315338  0.90999          2       0.187717
# ...
