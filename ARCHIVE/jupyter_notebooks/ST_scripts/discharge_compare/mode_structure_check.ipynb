# %%
import sys
script_path = '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools'
sys.path.insert(1, script_path)
from scanfile_tools import display_scanfile_info, which_scanfiles

# %%
# filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top'

# criteria_list = []
# displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
# df = display_scanfile_info(filepath, displayed_outputs)

# which_files = 'all'
# sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [1.7, 1], which_files)

# %%
# filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top'

# criteria_list = []
# displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
# df = display_scanfile_info(filepath, displayed_outputs)

# which_files = 'all'
# sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [2, 1], which_files)

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top'

criteria_list = []
displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
df = display_scanfile_info(filepath, displayed_outputs)

which_files = 'scanfiles0007'
sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [2, 1], which_files)
# Out:
#          scanfile suffix  kymin  nz0  hyp_z        x0
# 0   scanfiles0001   0001    0.1   96   -1.0  0.500000
# 1   scanfiles0001   0002    0.5   96   -1.0  0.500000
# 2   scanfiles0001   0003    1.0   96   -1.0  0.500000
# 3   scanfiles0001   0004    5.0   96   -1.0  0.500000
# 4   scanfiles0001   0005   10.0   96   -1.0  0.500000
# 5   scanfiles0001   0006   50.0   96   -1.0  0.500000
# 6   scanfiles0002   0001    0.1  128   -1.0  0.499925
# 7   scanfiles0002   0002    0.5  128   -1.0  0.499925
# 8   scanfiles0002   0003    1.0  128   -1.0  0.499925
# 9   scanfiles0002   0004    5.0  128   -1.0  0.499925
# 10  scanfiles0002   0005   10.0  128   -1.0  0.499925
# 11  scanfiles0002   0006   50.0  128   -1.0  0.499925
# 12  scanfiles0003   0001    0.1  128   -1.0  0.499925
# 13  scanfiles0003   0002    0.5  128   -1.0  0.499925
# 14  scanfiles0003   0003    1.0  128   -1.0  0.499925
# 15  scanfiles0003   0004    5.0  128   -1.0  0.499925
# ...
