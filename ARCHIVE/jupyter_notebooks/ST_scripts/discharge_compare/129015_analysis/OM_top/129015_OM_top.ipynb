# %%
# QUEUE

# DONE
# 10/04/20 5:30PM - 9 hrs run (0.1, 0.3, 0.5), nz0 = 256, hyp_z = -1
# 9/30/20 8PM - 9 hrs run (130, 170, 230)
# 9/29/20 8:30AM - 9 hrs run (200, 250, 300)
# 9/28/20 9AM - 7 hrs run (70, 150, 200)
#9/26/20 4:46PM - 9 hrs run (3, 10, 200)

# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')

from scanfile_tools_V2 import path_to_scanfile_info, display_scanfile_info, scanfile_mode_structures
from omega_to_df_plotting_V2 import omega_dataframes, display_omega_df, plot_gamma_omega, plot_omega_mode_structures, plot_omega_mode_structures_AUTO_LIMITER

# %% [markdown]
# ## OM Plots

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'

criteria_list = []
scanfile_outputs = ['nz0', 'hyp_z']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
omega_df = dataframes['omega_df']

display_omega_df(omega_df)
plot_omega_mode_structures_AUTO_LIMITER(omega_df)
# Out:
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 1   scanfiles0001   0001  128   -6.0    0.1          3     4.626211
# 22  scanfiles0009   0001  256   -1.0    0.1          3     3.502000
# 25  scanfiles0010   0001  256   -3.0    0.1          3     4.281000
# 27  scanfiles0011   0001  256   -5.0    0.1          3     3.448000
# 23  scanfiles0009   0002  256   -1.0    0.3          9     2.609000
# 24  scanfiles0009   0003  256   -1.0    0.5         14     2.055000
# 2   scanfiles0001   0002  128   -6.0    0.5         14     0.946000
# 3   scanfiles0001   0003  128   -6.0    0.7         20     0.912000
# 10  scanfiles0003   0001  128   -6.0    1.0         29     0.823000
# 7   scanfiles0002   0001  128   -6.0   10.0        289     1.569000
# 5   scanfiles0001   0005  128   -6.0   10.0        289     1.569000
# 12  scanfiles0003   0003  128   -6.0   30.0        866     0.999630
# 8   scanfiles0002   0002  128   -6.0   50.0       1443     0.558000
# 14  scanfiles0006   0001  128   -6.0   70.0       2020     5.507000
# 9   scanfiles0002   0003  128   -6.0  100.0       2886     9.729890
# 19  scanfiles0008   0001  128   -6.0  130.0       3752    15.502000
# 15  scanfiles0006   0002  128   -6.0  150.0       4330    17.196061
# 20  scanfiles0008   0002  128   -6.0  170.0       4907    23.842388
# 16  scanfiles0007   0001  128   -6.0  200.0       5773    42.269000
# 21  scanfiles0008   0003  128   -6.0  230.0       6639    65.698000
# 17  scanfiles0007   0002  128   -6.0  250.0       7216    82.083000
# 18  scanfiles0007   0003  128   -6.0  300.0       8659   112.880000
#
#      gamma(kHz)  omega(cs/a)   omega(kHz)      Gamma_ES          Q_ES  \
# 1     55.887562    -1.539673   -18.600224  2.072000e+06  5.286700e+06
# 22    42.306381    -2.686000   -32.448583  1.902000e+05  3.581000e+05
# 25    51.717195    -1.536000   -18.555854  1.120000e+06  2.477800e+06
# 27    41.654026    -1.023000   -12.358489  1.024700e+05  2.353500e+05
# 23    31.518374    -9.206000  -111.214318  4.610800e+09  9.435100e+09
# 24    24.825703   -15.206000  -183.698122  2.687000e+19  5.385300e+19
# 2     11.428280    -0.826000    -9.978604  8.770500e+01  2.481400e+02
# 3     11.017538    -0.416000    -5.025544  3.556100e+01  1.003000e+02
# 10     9.942362    -0.092000    -1.111418  1.970000e+01  4.485200e+01
# 7     18.954515    -4.749000   -57.370931  2.130400e+05  4.088900e+05
# 5     18.954515    -4.749000   -57.370931  2.130400e+05  4.088900e+05
# 12    12.076170    -7.494464   -90.537878  2.179800e+05  2.954600e+05
# 8      6.740994   -25.742000  -310.979683  1.833500e-03  2.700300e-03
# 14    66.528052   -39.178000  -473.295083  2.871300e+05  4.537900e+05
# 9    117.543244   -49.077373  -592.885784  1.631600e+10  2.601900e+10
# 19   187.273990   -72.237000  -872.668766  2.029900e+17  3.025500e+17
# 15   207.739319   -90.095070 -1088.405581  5.266500e+09  7.323900e+09
# 20   288.031162   -14.378755  -173.704474  5.007700e+24  6.733300e+24
# 16   510.636323   -23.294000  -281.406291  8.374000e+00  9.992800e+00
# 21   793.673499   -39.097000  -472.316552  1.053200e+16  1.362200e+16
# 17   991.614689   -54.427000  -657.512672  7.306000e+11  1.159500e+12
# 18  1363.661978  -108.004000 -1304.756806  2.174900e+11  3.020500e+11
#
#     Gamma_ES/Q_ES  Canik ratio
# 1        0.391927     0.051954
# 22       0.531137     0.070407
# 25       0.452014     0.059919
# 27       0.435394     0.057716
# 23       0.488686     0.064780
# 24       0.498951     0.066141
# 2        0.353450     0.046853
# 3        0.354546     0.046998
# 10       0.439222     0.058223
# 7        0.521020     0.069066
# 5        0.521020     0.069066
# 12       0.737765     0.097798
# 8        0.678999     0.090008
# 14       0.632738     0.083875
# 9        0.627080     0.083125
# 19       0.670930     0.088938
# 15       0.719084     0.095321
# 20       0.743722     0.098587
# 16       0.838003     0.111085
# 21       0.773161     0.102490
# 17       0.630099     0.083526
# 18       0.720046     0.095449
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 1  scanfiles0001   0001  128   -6.0    0.1          3     4.626211
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)   Gamma_ES       Q_ES  Gamma_ES/Q_ES  \
# 1   55.887562    -1.539673  -18.600224  2072000.0  5286700.0       0.391927
#
#    Canik ratio
# 1     0.051954
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 22.264891992144882
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0009/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 22  scanfiles0009   0001  256   -1.0    0.1          3        3.502
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 22   42.306381       -2.686  -32.448583  190200.0  358100.0       0.531137
#
#     Canik ratio
# 22     0.070407
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 14.450721362767252
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0010/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 25  scanfiles0010   0001  256   -3.0    0.1          3        4.281
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)   Gamma_ES       Q_ES  Gamma_ES/Q_ES  \
# 25   51.717195       -1.536  -18.555854  1120000.0  2477800.0       0.452014
#
#     Canik ratio
# 25     0.059919
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 34.20618556701031
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0011/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 27  scanfiles0011   0001  256   -5.0    0.1          3        3.448
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 27   41.654026       -1.023  -12.358489  102470.0  235350.0       0.435394
#
#     Canik ratio
# 27     0.057716
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 70.36368074200635
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0009/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 23  scanfiles0009   0002  256   -1.0    0.3          9        2.609
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 23   31.518374       -9.206 -111.214318  4.610800e+09  9.435100e+09
#
#     Gamma_ES/Q_ES  Canik ratio
# 23       0.488686      0.06478
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 23.74833259226323
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0009/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 24  scanfiles0009   0003  256   -1.0    0.5         14        2.055
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 24   24.825703      -15.206 -183.698122  2.687000e+19  5.385300e+19
#
#     Gamma_ES/Q_ES  Canik ratio
# 24       0.498951     0.066141
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 36.443647399641335
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 2  scanfiles0001   0002  128   -6.0    0.5         14        0.946
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES    Q_ES  Gamma_ES/Q_ES  \
# 2    11.42828       -0.826   -9.978604    87.705  248.14        0.35345
#
#    Canik ratio
# 2     0.046853
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.07910559397430683
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 3  scanfiles0001   0003  128   -6.0    0.7         20        0.912
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES   Q_ES  Gamma_ES/Q_ES  \
# 3   11.017538       -0.416   -5.025544    35.561  100.3       0.354546
#
#    Canik ratio
# 3     0.046998
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.08394846329351764
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0003/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 10  scanfiles0003   0001  128   -6.0    1.0         29        0.823
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES    Q_ES  Gamma_ES/Q_ES  \
# 10    9.942362       -0.092   -1.111418      19.7  44.852       0.439222
#
#     Canik ratio
# 10     0.058223
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.10734537699159452
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0002/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 7  scanfiles0002   0001  128   -6.0   10.0        289        1.569
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 7   18.954515       -4.749  -57.370931  213040.0  408890.0        0.52102
#
#    Canik ratio
# 7     0.069066
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.027575776631870205
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 5  scanfiles0001   0005  128   -6.0   10.0        289        1.569
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 5   18.954515       -4.749  -57.370931  213040.0  408890.0        0.52102
#
#    Canik ratio
# 5     0.069066
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.027575776631870205
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0003/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 12  scanfiles0003   0003  128   -6.0   30.0        866      0.99963
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 12    12.07617    -7.494464  -90.537878  217980.0  295460.0       0.737765
#
#     Canik ratio
# 12     0.097798
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.01867573011077543
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0002/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 8  scanfiles0002   0002  128   -6.0   50.0       1443        0.558
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES    Q_ES  Gamma_ES/Q_ES  \
# 8    6.740994      -25.742 -310.979683  0.001834  0.0027       0.678999
#
#    Canik ratio
# 8     0.090008
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.018963640486809284
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0006/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 14  scanfiles0006   0001  128   -6.0   70.0       2020        5.507
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  \
# 14   66.528052      -39.178 -473.295083  287130.0  453790.0       0.632738
#
#     Canik ratio
# 14     0.083875
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.01399414776883687
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0002/
#         scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 9  scanfiles0002   0003  128   -6.0  100.0       2886      9.72989
#
#    gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 9  117.543244   -49.077373 -592.885784  1.631600e+10  2.601900e+10
#
#    Gamma_ES/Q_ES  Canik ratio
# 9        0.62708     0.083125
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.04409313534945192
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0008/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 19  scanfiles0008   0001  128   -6.0  130.0       3752       15.502
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 19   187.27399      -72.237 -872.668766  2.029900e+17  3.025500e+17
#
#     Gamma_ES/Q_ES  Canik ratio
# 19        0.67093     0.088938
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.026934140309774826
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0006/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 15  scanfiles0006   0002  128   -6.0  150.0       4330    17.196061
#
#     gamma(kHz)  omega(cs/a)   omega(kHz)      Gamma_ES          Q_ES  \
# 15  207.739319    -90.09507 -1088.405581  5.266500e+09  7.323900e+09
#
#     Gamma_ES/Q_ES  Canik ratio
# 15       0.719084     0.095321
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.02045706336786149
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0008/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 20  scanfiles0008   0002  128   -6.0  170.0       4907    23.842388
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 20  288.031162   -14.378755 -173.704474  5.007700e+24  6.733300e+24
#
#     Gamma_ES/Q_ES  Canik ratio
# 20       0.743722     0.098587
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.004167518663554466
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0007/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 16  scanfiles0007   0001  128   -6.0  200.0       5773       42.269
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)  Gamma_ES    Q_ES  Gamma_ES/Q_ES  \
# 16  510.636323      -23.294 -281.406291     8.374  9.9928       0.838003
#
#     Canik ratio
# 16     0.111085
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.00385154149998107
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0008/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 21  scanfiles0008   0003  128   -6.0  230.0       6639       65.698
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 21  793.673499      -39.097 -472.316552  1.053200e+16  1.362200e+16
#
#     Gamma_ES/Q_ES  Canik ratio
# 21       0.773161      0.10249
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.003051191736715863
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0007/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 17  scanfiles0007   0002  128   -6.0  250.0       7216       82.083
#
#     gamma(kHz)  omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  \
# 17  991.614689      -54.427 -657.512672  7.306000e+11  1.159500e+12
#
#     Gamma_ES/Q_ES  Canik ratio
# 17       0.630099     0.083526
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.0028482696474929734
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0007/
#          scanfile suffix  nz0  hyp_z  kymin  n0_global  gamma(cs/a)  \
# 18  scanfiles0007   0003  128   -6.0  300.0       8659       112.88
#
#      gamma(kHz)  omega(cs/a)   omega(kHz)      Gamma_ES          Q_ES  \
# 18  1363.661978     -108.004 -1304.756806  2.174900e+11  3.020500e+11
#
#     Gamma_ES/Q_ES  Canik ratio
# 18       0.720046     0.095449
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.002483524246858758
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## No Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'

criteria_list = []
scanfile_outputs = ['nz0']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
no_omega_df = dataframes['no_omega_df']

display_omega_df(no_omega_df)
plot_omega_mode_structures_AUTO_LIMITER(no_omega_df)
# Out:
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 4   scanfiles0001   0004  128    5.0        144          0.0         0.0
# 6   scanfiles0001   0006  128   50.0          0          0.0         0.0
# 11  scanfiles0003   0002  128    5.0        144          0.0         0.0
# 13  scanfiles0005   0001  128   70.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  Gamma_ES/Q_ES  \
# 4           0.0         0.0  3.763900e-11 -1.178900e-11      -3.192722
# 6           0.0         0.0  1.494300e-05  2.216400e-05       0.674201
# 11          0.0         0.0  3.763900e-11 -1.178900e-11      -3.192722
# 13          0.0         0.0  5.409100e-05  1.231400e-04       0.439264
#
#     Canik ratio
# 4     -0.423226
# 6      0.089372
# 11    -0.423226
# 13     0.058229
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 4  scanfiles0001   0004  128    5.0        144          0.0         0.0
#
#    omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  Gamma_ES/Q_ES  \
# 4          0.0         0.0  3.763900e-11 -1.178900e-11      -3.192722
#
#    Canik ratio
# 4    -0.423226
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.11743264659270998
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 6  scanfiles0001   0006  128   50.0          0          0.0         0.0
#
#    omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  Canik ratio
# 6          0.0         0.0  0.000015  0.000022       0.674201     0.089372
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.0189819527996298
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0003/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 11  scanfiles0003   0002  128    5.0        144          0.0         0.0
#
#     omega(cs/a)  omega(kHz)      Gamma_ES          Q_ES  Gamma_ES/Q_ES  \
# 11          0.0         0.0  3.763900e-11 -1.178900e-11      -3.192722
#
#     Canik ratio
# 11    -0.423226
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.11743264659270998
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0005/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 13  scanfiles0005   0001  128   70.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)  Gamma_ES      Q_ES  Gamma_ES/Q_ES  Canik ratio
# 13          0.0         0.0  0.000054  0.000123       0.439264     0.058229
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.03537722657912335
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## All OM Simulations

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0011'

criteria_list = []
scanfile_outputs = ['kymin', 'nz0', 'hyp_z']

scan_df = path_to_scanfile_info(filepath, scanfile_outputs, criteria_list)

display_scanfile_info(scan_df)
# Out:
#         scanfile suffix  kymin  nz0  hyp_z
# 0  scanfiles0011   0001    0.1  256   -5.0
# 1  scanfiles0011   0002    0.3  256   -5.0

# %%
scanfile_mode_structures(scan_df, 1, 1)
# Out:
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0011/
#         scanfile suffix  kymin  nz0  hyp_z
# 0  scanfiles0011   0001    0.1  256   -5.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 70.36368074200635
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0011/
#         scanfile suffix  kymin  nz0  hyp_z
# 1  scanfiles0011   0002    0.3  256   -5.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.0679661988974848
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
