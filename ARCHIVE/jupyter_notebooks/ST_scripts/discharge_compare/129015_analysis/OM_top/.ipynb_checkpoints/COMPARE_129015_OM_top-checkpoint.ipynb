# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')
from scanfile_tools_V2 import path_to_scanfile_info, display_scanfile_info, scanfile_mode_structures
from omega_to_df_plotting_V2 import omega_dataframes, display_omega_df, plot_gamma_omega, plot_omega_mode_structures, plot_omega_mode_structures_AUTO_LIMITER

sys.path.insert(1, '/global/u1/j/joeschm/jojo_github')
from plotting_tools import plot_Gamma_Q_ratio

# %% [markdown]
# ## OM Plots

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## OM 30 perc NE plus

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_plus/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## OM 30 perc NE minus

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_minus/'
plot_gamma_omega(filepath)

# %%
f1 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'
f2 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_plus/'
f3 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_minus/'

plot_Gamma_Q_ratio(f1, f2, f3)
# Out:
# filepath 1: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/
# filepath 2: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_plus/
# filepath 3: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_minus/

# %%
f1 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'
f2 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_plus/'
f3 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/OM_top_30NE_minus/'

plot_Canik_ratio(f1, f2, f3, 0.122)

# %% [markdown]
# ## All PE Simulations

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'

criteria_list = []
scanfile_outputs = ['nz0', 'kymin']

scan_df = path_to_scanfile_info(filepath, scanfile_outputs, criteria_list)

display_scanfile_info(scan_df)
# Out:
#          scanfile suffix  nz0  kymin
# 0   scanfiles0000   0001  128    0.3
# 1   scanfiles0001   0001  128    0.1
# 2   scanfiles0001   0002  128    0.5
# 3   scanfiles0001   0003  128    0.7
# 4   scanfiles0001   0004  128    5.0
# 5   scanfiles0001   0005  128   10.0
# 6   scanfiles0001   0006  128   50.0
# 7   scanfiles0002   0001  128   10.0
# 8   scanfiles0002   0002  128   50.0
# 9   scanfiles0002   0003  128  100.0
# 10  scanfiles0003   0001  128    1.0
# 11  scanfiles0003   0002  128    5.0
# 12  scanfiles0003   0003  128   30.0
# 13  scanfiles0005   0001  128   70.0
# 14  scanfiles0006   0001  128   70.0
# 15  scanfiles0006   0002  128  150.0
# 16  scanfiles0007   0001  128  200.0
# 17  scanfiles0007   0002  128  250.0
# 18  scanfiles0007   0003  128  300.0
# 19  scanfiles0008   0001  128  130.0
# 20  scanfiles0008   0002  128  170.0
# 21  scanfiles0008   0003  128  230.0
# 22  scanfiles0009   0001  256    0.1
# 23  scanfiles0009   0002  256    0.3
# ...

# %%
scanfile_mode_structures(scan_df, 1, 1)
# Out:
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0000/
#         scanfile suffix  nz0  kymin
# 0  scanfiles0000   0001  128    0.3
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.17098528756130185
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  kymin
# 1  scanfiles0001   0001  128    0.1
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 22.264891992144882
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  kymin
# 2  scanfiles0001   0002  128    0.5
# Calculating growth rate from phi.
# ...
