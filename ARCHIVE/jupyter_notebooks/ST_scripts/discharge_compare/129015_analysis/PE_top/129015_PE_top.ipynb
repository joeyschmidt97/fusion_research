# %%
# QUEUE

# DONE
# 10/04/20 11:30AM - continue scan 9 hrs run scanfiles0008 (200, 250, 300)
# 9/29/20 8AM - 9 hrs run (200, 250, 300)
# 9/27/20 12PM - 9 hrs run (70, 150, 200)
#9/24/20 11am - 9 hrs run (50, 100, 150)

# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')

from scanfile_tools_V2 import path_to_scanfile_info, display_scanfile_info, scanfile_mode_structures
from omega_to_df_plotting_V2 import omega_dataframes, display_omega_df, plot_gamma_omega, plot_omega_mode_structures, plot_omega_mode_structures_AUTO_LIMITER

# %% [markdown]
# ## PE Plots

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/'
plot_gamma_omega(filepath)

# %% [markdown]
# # Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/'

criteria_list = []
scanfile_outputs = ['nz0']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
omega_df = dataframes['omega_df']

display_omega_df(omega_df)
plot_omega_mode_structures_AUTO_LIMITER(omega_df)
# Out:
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0   scanfiles0000   0001  128    0.3          7     0.210000    3.595643
# 3   scanfiles0001   0002  128    0.7         17     0.843000   14.433937
# 4   scanfiles0001   0003  128    1.0         24     1.206000   20.649263
# 5   scanfiles0001   0004  128    5.0        120     0.254000    4.349016
# 8   scanfiles0003   0001  128   10.0        240     0.037000    0.633518
# 9   scanfiles0003   0002  128   30.0        721     0.524000    8.971985
# 13  scanfiles0006   0001  256   50.0       1201     0.998000   17.087864
# 16  scanfiles0007   0001  256   70.0       1682     1.525000   26.111215
# 14  scanfiles0006   0002  256  100.0       2402     2.938000   50.304755
# 17  scanfiles0007   0002  256  150.0       3603     2.679918   45.885847
#
#     omega(cs/a)  omega(kHz)
# 0     -1.178000  -20.169844
# 3     -2.356000  -40.339688
# 4     -3.017000  -51.657401
# 5     -9.090000 -155.639966
# 8     -0.194000   -3.321689
# 9     -6.321000 -108.228848
# 13    -9.804000 -167.865151
# 16   -14.595000 -249.897173
# 14   -23.402000 -400.691582
# 17   -37.128751 -635.722501
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0000/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0  scanfiles0000   0001  128    0.3          7         0.21    3.595643
#
#    omega(cs/a)  omega(kHz)
# 0       -1.178  -20.169844
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 5.408614948446716
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 3  scanfiles0001   0002  128    0.7         17        0.843   14.433937
#
#    omega(cs/a)  omega(kHz)
# 3       -2.356  -40.339688
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 2.5082984227273766
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 4  scanfiles0001   0003  128    1.0         24        1.206   20.649263
#
#    omega(cs/a)  omega(kHz)
# 4       -3.017  -51.657401
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 2.47304933710063
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 5  scanfiles0001   0004  128    5.0        120        0.254    4.349016
#
#    omega(cs/a)  omega(kHz)
# 5        -9.09 -155.639966
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 3.076641266119578
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0003/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 8  scanfiles0003   0001  128   10.0        240        0.037    0.633518
#
#    omega(cs/a)  omega(kHz)
# 8       -0.194   -3.321689
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.01159729344947415
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0003/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 9  scanfiles0003   0002  128   30.0        721        0.524    8.971985
#
#    omega(cs/a)  omega(kHz)
# 9       -6.321 -108.228848
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.11314626601855943
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0006/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 13  scanfiles0006   0001  256   50.0       1201        0.998   17.087864
#
#     omega(cs/a)  omega(kHz)
# 13       -9.804 -167.865151
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.1014506492014248
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0007/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 16  scanfiles0007   0001  256   70.0       1682        1.525   26.111215
#
#     omega(cs/a)  omega(kHz)
# 16      -14.595 -249.897173
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.08386655047927301
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0006/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 14  scanfiles0006   0002  256  100.0       2402        2.938   50.304755
#
#     omega(cs/a)  omega(kHz)
# 14      -23.402 -400.691582
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.053118737474949905
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0007/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 17  scanfiles0007   0002  256  150.0       3603     2.679918   45.885847
#
#     omega(cs/a)  omega(kHz)
# 17   -37.128751 -635.722501
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.04084085739885588
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## No Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/'

criteria_list = []
scanfile_outputs = ['nz0']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
no_omega_df = dataframes['no_omega_df']

display_omega_df(no_omega_df)
plot_omega_mode_structures_AUTO_LIMITER(no_omega_df)
# Out:
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 1   scanfiles0000   0002  128    0.5          0          0.0         0.0
# 2   scanfiles0001   0001  128    0.1          2          0.0         0.0
# 6   scanfiles0001   0005  128   10.0          0          0.0         0.0
# 7   scanfiles0002   0001  128   10.0          0          0.0         0.0
# 10  scanfiles0003   0003  128   50.0          0          0.0         0.0
# 11  scanfiles0004   0001  256    0.1          0          0.0         0.0
# 12  scanfiles0005   0001  256    0.1          0          0.0         0.0
# 15  scanfiles0006   0003  256  150.0          0          0.0         0.0
# 18  scanfiles0008   0001  256  200.0       4804          0.0         0.0
# 19  scanfiles0008   0002  256  250.0       6005          0.0         0.0
# 20  scanfiles0008   0003  256  300.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 1           0.0         0.0
# 2           0.0         0.0
# 6           0.0         0.0
# 7           0.0         0.0
# 10          0.0         0.0
# 11          0.0         0.0
# 12          0.0         0.0
# 15          0.0         0.0
# 18          0.0         0.0
# 19          0.0         0.0
# 20          0.0         0.0
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0000/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 1  scanfiles0000   0002  128    0.5          0          0.0         0.0
#
#    omega(cs/a)  omega(kHz)
# 1          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 2.7969741650105773
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 2  scanfiles0001   0001  128    0.1          2          0.0         0.0
#
#    omega(cs/a)  omega(kHz)
# 2          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 445.1476793248945
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0001/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 6  scanfiles0001   0005  128   10.0          0          0.0         0.0
#
#    omega(cs/a)  omega(kHz)
# 6          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.009395759193357058
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0002/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 7  scanfiles0002   0001  128   10.0          0          0.0         0.0
#
#    omega(cs/a)  omega(kHz)
# 7          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.010099071207430341
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0003/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 10  scanfiles0003   0003  128   50.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 10          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.1012379866427757
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0004/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 11  scanfiles0004   0001  256    0.1          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 11          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 458.26380485319413
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0005/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 12  scanfiles0005   0001  256    0.1          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 12          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 6804.130557492446
# WARNING: neg_loc < corr_time
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0006/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 15  scanfiles0006   0003  256  150.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 15          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.04091135985478748
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0008/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 18  scanfiles0008   0001  256  200.0       4804          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 18          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.03580328349457637
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0008/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 19  scanfiles0008   0002  256  250.0       6005          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 19          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.01714022319262494
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0008/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 20  scanfiles0008   0003  256  300.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 20          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.1790521755996638
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## All PE Simulations

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0007'

criteria_list = []
scanfile_outputs = ['kymin', 'nz0', 'hyp_z']

scan_df = path_to_scanfile_info(filepath, scanfile_outputs, criteria_list)

display_scanfile_info(scan_df)
# Out:
#         scanfile suffix  kymin  nz0  hyp_z
# 0  scanfiles0007   0001   70.0  256   -6.0
# 1  scanfiles0007   0002  150.0  256   -6.0

# %%
scanfile_mode_structures(scan_df, 1, 1)
# Out:
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0007/
#         scanfile suffix  kymin  nz0  hyp_z
# 0  scanfiles0007   0001   70.0  256   -6.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.08386655047927301
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/scanfiles0007/
#         scanfile suffix  kymin  nz0  hyp_z
# 1  scanfiles0007   0002  150.0  256   -6.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# /global/common/software/nersc/cori-2022q1/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:234: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   for label in axis.get_ticklabels()])
# QiEM/QiES: -0.04084085739885588
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
