# %%
#Convergence test at lowest kymin, kymax, and peak(s), and minimum peaks (where mode changes)
#Ballooning structures for each of the above points to check resolution (nz0 x nx0)

# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')

from plot_PE_NE_OM_points import multiplot_PE_NE_OM
from omega_to_df_plotting_V2 import omega_dataframes, plot_gamma_omega

# %% [markdown]
# ## Three Points of Interest

# %%
discharge_path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129015'

# %%
point_list = [.87, .85, .936]
multiplot_PE_NE_OM(discharge_path, point_list, False)

# %% [markdown]
# ## PE Plots

# %%
# Notes
# kymin = [0.3 - 150], continue scan for 200 -300 runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_PE_top/'
plot_gamma_omega(filepath, 'kymin')

# %% [markdown]
# ## NE Plots

# %%
# Notes
# kymin = [0.3 - 150], scans for 200-300 decay

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_NE_top/'
plot_gamma_omega(filepath, 'kymin')

# %% [markdown]
# ## OM Plots

# %%
# Notes
# kymin = [0.1 - 300] 
# What is happening with omega split at the end?

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129015/Impurities_OM_top/'
plot_gamma_omega(filepath, 'kymin')
