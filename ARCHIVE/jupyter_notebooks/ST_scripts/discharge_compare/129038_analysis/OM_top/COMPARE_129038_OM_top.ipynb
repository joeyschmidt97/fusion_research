# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')
from scanfile_tools_V2 import path_to_scanfile_info, display_scanfile_info, scanfile_mode_structures
from omega_to_df_plotting_V2 import omega_dataframes, display_omega_df, plot_gamma_omega, plot_omega_mode_structures, plot_omega_mode_structures_AUTO_LIMITER

sys.path.insert(1, '/global/u1/j/joeschm/jojo_github')
from plotting_tools import plot_Gamma_Q_ratio, plot_Canik_ratio

# %% [markdown]
# ## OM Plots

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## OM 30 perc NE plus

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_plus/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## OM 30 perc NE minus

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_minus/'
plot_gamma_omega(filepath)

# %%
f1 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/'
f2 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_plus/'
f3 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_minus/'

plot_Gamma_Q_ratio(f1, f2, f3)
# Out:
# filepath 1: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/
# filepath 2: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_plus/
# filepath 3: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_minus/
# filepath /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/
# ratio: 0.1232877297609039
# filepath /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_plus/
# ratio: 0.22572697606736158
# filepath /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/OM_top_30NE_minus/
# ratio: 0.03562943284252976

# %%
f1 = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/'

plot_Canik_ratio(f1, 0.161)
# Out:
# filepath 1: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/

# %% [markdown]
# ## All PE Simulations

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/'

criteria_list = []
scanfile_outputs = ['nz0', 'kymin']

scan_df = path_to_scanfile_info(filepath, scanfile_outputs, criteria_list)

display_scanfile_info(scan_df)
# Out:
#          scanfile suffix  nz0  kymin
# 0   scanfiles0000   0001  512    0.1
# 1   scanfiles0001   0001  512    0.5
# 2   scanfiles0002   0001  512    5.0
# 3   scanfiles0003   0001  128    1.0
# 4   scanfiles0003   0002  128   30.0
# 5   scanfiles0004   0001  512   10.0
# 6   scanfiles0005   0001  512   50.0
# 7   scanfiles0006   0001  512  100.0
# 8   scanfiles0007   0001  512  200.0
# 9   scanfiles0008   0001  128    0.1
# 10  scanfiles0008   0002  128    0.3
# 11  scanfiles0008   0003  128    0.5
# 12  scanfiles0009   0001  128    0.7
# 13  scanfiles0009   0002  128    0.9
# 14  scanfiles0009   0003  128    1.0
# 15  scanfiles0009   0004  128    5.0
# 16  scanfiles0009   0005  128   10.0
# 17  scanfiles0009   0006  128   50.0
# 18  scanfiles0010   0001  128  100.0
# 19  scanfiles0010   0002  128  150.0
# 20  scanfiles0011   0001  128    5.0
# 21  scanfiles0011   0002  128   10.0
# 22  scanfiles0012   0001  128    3.0
# 23  scanfiles0012   0002  128   10.0
# ...

# %%
scanfile_mode_structures(scan_df, 1, 1)
# Out:
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/scanfiles0000/
#         scanfile suffix  nz0  kymin
# 0  scanfiles0000   0001  512    0.1
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 0.26018537675342407
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/scanfiles0001/
#         scanfile suffix  nz0  kymin
# 1  scanfiles0001   0001  512    0.5
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: -0.005124596664463709
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/scanfiles0002/
#         scanfile suffix  nz0  kymin
# 2  scanfiles0002   0001  512    5.0
# Calculating growth rate from phi.
# ...
