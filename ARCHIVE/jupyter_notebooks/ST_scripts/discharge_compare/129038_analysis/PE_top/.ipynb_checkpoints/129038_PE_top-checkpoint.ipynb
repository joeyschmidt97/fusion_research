# %%
# QUEUE


# DONE
#9/26/20 2:31PM - continue scan 9 hrs for scanfiles0006
#9/23/20 11:40AM - 9 hrs run
#9/22/20 12pm - 9 hrs run

# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')

from scanfile_tools_V2 import path_to_scanfile_info, display_scanfile_info, scanfile_mode_structures
from omega_to_df_plotting_V2 import omega_dataframes, display_omega_df, plot_gamma_omega, plot_omega_mode_structures, plot_omega_mode_structures_AUTO_LIMITER

# %% [markdown]
# ## PE Plots

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/'
plot_gamma_omega(filepath)

# %% [markdown]
# ## Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/'

criteria_list = []
scanfile_outputs = ['nz0']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
omega_df = dataframes['omega_df']

display_omega_df(omega_df)
plot_omega_mode_structures_AUTO_LIMITER(omega_df)
# Out:
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 36  scanfiles0006   0001   96    0.3          8     0.020256    0.696091
# 1   scanfiles0000   0002   96    0.5         14     0.044128    1.516438
# 13  scanfiles0002   0002   96    0.5         14     0.027511    0.945383
# 55  scanfiles0009   0002   96    0.5         14     0.025008    0.859366
#
#     omega(cs/a)  omega(kHz)
# 36     0.659042   22.647529
# 1      1.090619   37.478378
# 13     1.069782   36.762315
# 55     1.080211   37.120706
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0006/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 36  scanfiles0006   0001   96    0.3          8     0.020256    0.696091
#
#     omega(cs/a)  omega(kHz)
# 36     0.659042   22.647529
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 21.317193930041153
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0000/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 1  scanfiles0000   0002   96    0.5         14     0.044128    1.516438
#
#    omega(cs/a)  omega(kHz)
# 1     1.090619   37.478378
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 25.339088828791347
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0002/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 13  scanfiles0002   0002   96    0.5         14     0.027511    0.945383
#
#     omega(cs/a)  omega(kHz)
# 13     1.069782   36.762315
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 16.253938691758794
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0009/
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 55  scanfiles0009   0002   96    0.5         14     0.025008    0.859366
#
#     omega(cs/a)  omega(kHz)
# 55     1.080211   37.120706
# Calculating growth rate from phi.
# Calculating growth rate from apar.
# QiEM/QiES: 28.38191211174182
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## No Omega Runs

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/'

criteria_list = []
scanfile_outputs = ['nz0']

dataframes = omega_dataframes(filepath, scanfile_outputs, criteria_list)
no_omega_df = dataframes['no_omega_df']

display_omega_df(no_omega_df)
plot_omega_mode_structures_AUTO_LIMITER(no_omega_df)
# Out:
#          scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0   scanfiles0000   0001   96    0.1          3          0.0         0.0
# 2   scanfiles0000   0003   96    1.0         28          0.0         0.0
# 3   scanfiles0000   0004   96    5.0        140          0.0         0.0
# 4   scanfiles0000   0005   96   10.0        280          0.0         0.0
# 5   scanfiles0000   0006   96   30.0        840          0.0         0.0
# 6   scanfiles0001   0001   96    0.1          0          0.0         0.0
# 7   scanfiles0001   0002   96    0.5          0          0.0         0.0
# 8   scanfiles0001   0003   96    1.0          0          0.0         0.0
# 9   scanfiles0001   0004   96    5.0          0          0.0         0.0
# 10  scanfiles0001   0005   96   10.0          0          0.0         0.0
# 11  scanfiles0001   0006   96   30.0          0          0.0         0.0
# 12  scanfiles0002   0001   96    0.1          3          0.0         0.0
# 14  scanfiles0002   0003   96    1.0         28          0.0         0.0
# 15  scanfiles0002   0004   96    5.0        140          0.0         0.0
# 16  scanfiles0002   0005   96   10.0        280          0.0         0.0
# 17  scanfiles0002   0006   96   30.0        840          0.0         0.0
# 18  scanfiles0003   0001   96    0.1          0          0.0         0.0
# 19  scanfiles0003   0002   96    0.5          0          0.0         0.0
# 20  scanfiles0003   0003   96    1.0          0          0.0         0.0
# 21  scanfiles0003   0004   96    5.0          0          0.0         0.0
# 22  scanfiles0003   0005   96   10.0          0          0.0         0.0
# 23  scanfiles0003   0006   96   30.0          0          0.0         0.0
# 24  scanfiles0004   0001   96    0.1          3          0.0         0.0
# 25  scanfiles0004   0002   96    1.0         28          0.0         0.0
# 26  scanfiles0004   0003   96    5.0        140          0.0         0.0
# 27  scanfiles0004   0004   96   10.0        280          0.0         0.0
# 28  scanfiles0004   0005   96   50.0       1401          0.0         0.0
# 29  scanfiles0004   0006   96  100.0       2801          0.0         0.0
# 30  scanfiles0005   0001   96    0.1          0          0.0         0.0
# 31  scanfiles0005   0002   96    0.7          0          0.0         0.0
# 32  scanfiles0005   0003   96    1.0          0          0.0         0.0
# 33  scanfiles0005   0004   96    5.0          0          0.0         0.0
# 34  scanfiles0005   0005   96   10.0          0          0.0         0.0
# 35  scanfiles0005   0006   96   30.0          0          0.0         0.0
# 37  scanfiles0006   0002   96   30.0        840          0.0         0.0
# 38  scanfiles0006   0003   96   70.0       1961          0.0         0.0
# 39  scanfiles0006   0004   96  150.0       4202          0.0         0.0
# 40  scanfiles0006   0005   96  200.0       5602          0.0         0.0
# 41  scanfiles0006   0006   96  250.0       7003          0.0         0.0
# 42  scanfiles0007   0001   96   70.0          0          0.0         0.0
# 43  scanfiles0007   0002   96  100.0          0          0.0         0.0
# 44  scanfiles0007   0003   96  120.0          0          0.0         0.0
# 45  scanfiles0007   0004   96  150.0          0          0.0         0.0
# 46  scanfiles0007   0005   96  180.0          0          0.0         0.0
# 47  scanfiles0007   0006   96  200.0          0          0.0         0.0
# 48  scanfiles0008   0001   96   70.0          0          0.0         0.0
# 49  scanfiles0008   0002   96  100.0          0          0.0         0.0
# 50  scanfiles0008   0003   96  120.0          0          0.0         0.0
# 51  scanfiles0008   0004   96  150.0          0          0.0         0.0
# 52  scanfiles0008   0005   96  180.0          0          0.0         0.0
# 53  scanfiles0008   0006   96  200.0          0          0.0         0.0
# 54  scanfiles0009   0001   96    0.1          0          0.0         0.0
# 56  scanfiles0009   0003   96    1.0          0          0.0         0.0
# 57  scanfiles0009   0004   96    5.0          0          0.0         0.0
# 58  scanfiles0009   0005   96   10.0          0          0.0         0.0
# 59  scanfiles0009   0006   96   50.0          0          0.0         0.0
#
#     omega(cs/a)  omega(kHz)
# 0           0.0         0.0
# 2           0.0         0.0
# 3           0.0         0.0
# 4           0.0         0.0
# 5           0.0         0.0
# 6           0.0         0.0
# 7           0.0         0.0
# 8           0.0         0.0
# 9           0.0         0.0
# 10          0.0         0.0
# 11          0.0         0.0
# 12          0.0         0.0
# 14          0.0         0.0
# 15          0.0         0.0
# 16          0.0         0.0
# 17          0.0         0.0
# 18          0.0         0.0
# 19          0.0         0.0
# 20          0.0         0.0
# 21          0.0         0.0
# 22          0.0         0.0
# 23          0.0         0.0
# 24          0.0         0.0
# 25          0.0         0.0
# 26          0.0         0.0
# 27          0.0         0.0
# 28          0.0         0.0
# 29          0.0         0.0
# 30          0.0         0.0
# 31          0.0         0.0
# 32          0.0         0.0
# 33          0.0         0.0
# 34          0.0         0.0
# 35          0.0         0.0
# 37          0.0         0.0
# 38          0.0         0.0
# 39          0.0         0.0
# 40          0.0         0.0
# 41          0.0         0.0
# 42          0.0         0.0
# 43          0.0         0.0
# 44          0.0         0.0
# 45          0.0         0.0
# 46          0.0         0.0
# 47          0.0         0.0
# 48          0.0         0.0
# 49          0.0         0.0
# 50          0.0         0.0
# 51          0.0         0.0
# 52          0.0         0.0
# 53          0.0         0.0
# 54          0.0         0.0
# 56          0.0         0.0
# 57          0.0         0.0
# 58          0.0         0.0
# 59          0.0         0.0
# /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0000/
#         scanfile suffix  nz0  kymin  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0  scanfiles0000   0001   96    0.1          3          0.0         0.0
#
#    omega(cs/a)  omega(kHz)
# 0          0.0         0.0
# Calculating growth rate from phi.
# Calculating growth rate from apar.

# %% [markdown]
# ## All PE Simulations

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/scanfiles0006'

criteria_list = []
scanfile_outputs = ['nz0', 'kymin', 'x0', 'hyp_z']

scan_df = path_to_scanfile_info(filepath, scanfile_outputs, criteria_list)

display_scanfile_info(scan_df)

# %%
scanfile_mode_structures(scan_df, 1, 1)
