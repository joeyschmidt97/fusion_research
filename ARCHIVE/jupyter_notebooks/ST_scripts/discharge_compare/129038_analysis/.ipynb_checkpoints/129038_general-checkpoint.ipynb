# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')

from plot_PE_NE_OM_points import multiplot_PE_NE_OM
from omega_to_df_plotting_V2 import omega_dataframes, plot_gamma_omega

# %% [markdown]
# ## Three Points of Interest

# %%
discharge_path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129038'

# %%
point_list = [.5, .655, .91]
# multiplot_PE_NE_OM(discharge_path, point_list, False)

# %% [markdown]
# ## PE Plots

# %%
# Notes
# kymin = [0.3 - 0.5], modes seem to be stable or its too close to the core

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top/'
plot_gamma_omega(filepath, 'kymin')

# %% [markdown]
# ## NE Plots

# %%
# Notes
# kymin = [0.1 - 100], beyond 100 modes stabilize
# MTMs present until kymin 50?

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/'
plot_gamma_omega(filepath, 'kymin')

# %% [markdown]
# ## OM Plots

# %%
# Notes
# kymin = [0.1 - 250]
# Split in omega similar to 129015 case?

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top/'
plot_gamma_omega(filepath, 'kymin')
