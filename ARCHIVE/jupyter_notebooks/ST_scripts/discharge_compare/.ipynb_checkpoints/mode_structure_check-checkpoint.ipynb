# %%
import sys
script_path = '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools'
sys.path.insert(1, script_path)
from scanfile_tools import display_scanfile_info, which_scanfiles

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top'

criteria_list = []
displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
df = display_scanfile_info(filepath, displayed_outputs)

which_files = 'all'
sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [1.7, 1], which_files)
# Out:
#          scanfile suffix  kymin  nz0  hyp_z        x0
# 0   scanfiles0000   0001    0.1  512   -2.0  0.655012
# 1   scanfiles0001   0001    0.1  512   -2.0  0.655012
# 2   scanfiles0002   0001    5.0  256   -6.0  0.655012
# 3   scanfiles0002   0002    1.0  256   -6.0  0.655012
# 4   scanfiles0002   0003    0.5  256   -6.0  0.655012
# 5   scanfiles0003   0001   10.0  256   -6.0  0.655012
# 6   scanfiles0004   0001   70.0  256   -6.0  0.655012
# 7   scanfiles0005   0001    1.0  256   -6.0  0.655012
# 8   scanfiles0006   0001    1.0  128   -6.0  0.655012
# 9   scanfiles0007   0001    0.1  128   -6.0  0.655012
# 10  scanfiles0008   0001  200.0  256   -6.0  0.655012
# 11  scanfiles0009   0001    0.1  512   -6.0  0.655012
# 12  scanfiles0010   0001    0.3  128   -6.0  0.655012
# 13  scanfiles0010   0002    0.5  128   -6.0  0.655012
# 14  scanfiles0010   0003    0.7  128   -6.0  0.655012
# 15  scanfiles0010   0004    5.0  128   -6.0  0.655012
# 16  scanfiles0010   0005   10.0  128   -6.0  0.655012
# 17  scanfiles0010   0006   50.0  128   -6.0  0.655012
# 18  scanfiles0011   0001  100.0  128   -6.0  0.655012
# 19  scanfiles0011   0002  150.0  128   -6.0  0.655012
# 20  scanfiles0011   0003  200.0  128   -6.0  0.655012
# which_scanfiles:  all all
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ['X_scanfiles0005', 'X_scanfiles0006', 'X_scanfiles0007', 'X_scanfiles0010', 'scanfiles0000', 'scanfiles0001', 'scanfiles0002', 'scanfiles0003', 'scanfiles0004', 'scanfiles0005', 'scanfiles0006', 'scanfiles0007', 'scanfiles0008', 'scanfiles0009', 'scanfiles0010', 'scanfiles0011']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0000
# all scans: 0001
#         scanfile suffix  kymin  nz0  hyp_z        x0
# 0  scanfiles0000   0001    0.1  512   -2.0  0.655012
# Calculating growth rate from phi.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0001
# all scans: 0001
#         scanfile suffix  kymin  nz0  hyp_z        x0
# 0  scanfiles0001   0001    0.1  512   -2.0  0.655012

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top'

criteria_list = []
displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
df = display_scanfile_info(filepath, displayed_outputs)

which_files = 'all'
sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [2, 1], which_files)

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top'

criteria_list = ['nz0 == 128']
displayed_outputs = ['kymin', 'nz0', 'hyp_z', 'x0']
df = display_scanfile_info(filepath, displayed_outputs)

which_files = 'all'
sdf = which_scanfiles(filepath, criteria_list, displayed_outputs, [2, 1], which_files)
