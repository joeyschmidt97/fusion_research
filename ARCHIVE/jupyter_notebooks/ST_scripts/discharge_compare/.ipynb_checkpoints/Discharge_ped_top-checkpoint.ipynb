# %%
import sys
sys.path.insert(1, '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools')
from make_profiles_iterdb import create_profiles, auto_create_profiles
from plot_profiles_iterdb import plot_profiles, multi_plot_profiles
from pedestal_tools import pedestal_points, pedestal_points_scaled

from knee_locator import KneeLocator, find_shape
from data_generator import DataGenerator

import numpy as np
import matplotlib.pyplot as plt

# %%
# x, y = DataGenerator.figure2()

# kneedle = KneeLocator(x, y, S=1.0, curve="concave", direction="increasing")
# kneedle.plot_knee_normalized()

# %%
path_129015 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129015/'
path_129038 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129038/'
path_132543 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/132543/'
path_132588 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/132588/'
path_139047 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/139047/'
path_139057 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/139057/'
path_141125 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141125/'
path_141133 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141133/'
path_141309 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141309/'

paths = [path_129015, path_129038, path_132543, path_132588, path_139047, path_139057, path_141125, path_141133, path_141309]
for path in paths:
    profile_dict, g_plot_dict = auto_create_profiles(path)
    rhot = profile_dict['PE']['rhot']
    pe = profile_dict['PE']['arr']
    ne = profile_dict['NE']['arr']
    
    x_lim = 0
    pre_e_top, ped_mid, ped_bot = pedestal_points(rhot,pe,1, x_lim)
    den_e_top, ped_mid, ped_bot = pedestal_points(rhot,ne,1, x_lim)
    
    print('pre_e_top:', pre_e_top, 'for path', path)
    print('den_e__top:', den_e_top, 'for path', path)
    print('')
    print('')
# Out:
# ped_top: 0.1316756 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/129015/
# ped_top: 0.8442835 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/129015/
# ped_top: 0.4951796 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/129038/
# ped_top: 0.6572597 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/129038/
# ped_top: 0.8350326 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/132543/
# ped_top: 0.9096597 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/132543/
# ped_top: 0.7075778 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/132588/
# ped_top: 0.4913259 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/132588/
# ped_top: 0.05964181 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/139047/
# ped_top: 0.9350174 for path /global/homes/j/joeschm/st_research/NSTXU_discharges/139047/
# ...

# %%
#Filepath for 129038
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129038/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0.1
scale = 2
pedestal_points(rhot,pe,1, x_lim)
# pedestal_points_scaled(rhot,pe,1, x_lim, 2)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/129038/
# (0.4951796, 0.7868739, 0.9437095)

# %%
#Filepath for 129015
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129015/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0.01
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, 2)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, 2)

kneedle = KneeLocator(rhot, pe, S=1.0, curve="concave", direction="increasing")
kneedle.plot_knee_normalized()
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/129015/

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 132543
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/132543/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0.7
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, 2)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)

kneedle = KneeLocator(rhot, pe, S=1.0, curve="concave", direction="increasing")
kneedle.plot_knee_normalized()
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/132543/

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 132588
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/132588/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0
scale = 1
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/132588/
# (0.6573854, 0.8139557, 0.9745214)

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 139047
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/139047/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)

a = 2000
x = rhot[-a:]
y = ne[-a:]

print(x, y)

kneedle = KneeLocator(x, y, S=1.0, curve="concave", direction="increasing")
kneedle.plot_knee_normalized()
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/139047/
# [0.5002018 0.5004515 0.5007013 ... 0.9989536 0.9992033 0.9994531] [6.647446e+19 6.646600e+19 6.645753e+19 ... 3.047245e+19 3.042335e+19
#  3.037430e+19]

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 139057
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/139057/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0.6
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/139057/
# (0.9166964, 0.9426591, 0.967124)

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 141125
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141125/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/141125/
# (0.7167744, 0.851391, 0.9710225)

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 141133
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141133/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/141133/
# (0.6743956, 0.8045676, 0.9817114)

# %%
path = '/global/homes/j/joeschm/st_research/NSTXU_discharges/'

#Filepath for 141309
path_discharge = '/global/homes/j/joeschm/st_research/NSTXU_discharges/141309/'
profile_dict, g_plot_dict = auto_create_profiles(path_discharge)

rhot = profile_dict['PE']['rhot']
pe = profile_dict['PE']['arr']
ne = profile_dict['NE']['arr']
print(path_discharge)

x_lim = 0
pedestal_points(rhot,pe,1, x_lim)
pedestal_points_scaled(rhot,pe,1, x_lim, scale)

pedestal_points(rhot,ne,1, x_lim)
pedestal_points_scaled(rhot,ne,1, x_lim, scale)
# Out:
# /global/homes/j/joeschm/st_research/NSTXU_discharges/141309/
# (0.880695, 0.930616, 0.9628151)

# %%
a = np.average([1,3])

print(a)
# Out:
# 2.0

# %%
from scipy.signal import savgol_filter
size = 100
x = np.arange(0,size)

y = np.random.randint(-5, 10, size=len(x))


a = plt.plot(x,y)

y = savgol_filter(y, 21, 2)

a = plt.plot(x,y)
plt.show()
