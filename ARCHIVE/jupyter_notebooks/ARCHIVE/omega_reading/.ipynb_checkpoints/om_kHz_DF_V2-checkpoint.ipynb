# %% [markdown]
# ### Import Necessary Libraries

# %%
import sys

script_path = '/global/u1/j/joeschm/jojo_github/ST_research/coding_tools'
sys.path.insert(1, script_path)
from omega_to_df_plotting import omega_df, plot_omega_gamma, mode_structures_of_points
# from scanfile_tools import display_scanfile_info, which_scanfiles

# %%
filepath = "/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top"

criteria_list = []
displayed_outputs = ['nz0', 'hyp_z', 'x0', 'kymin']
Imp_NE_top_129038 = omega_df(filepath, criteria_list, displayed_outputs)

df_dict= {'129038 - NE': {'dict': Imp_NE_top_129038, 'marker_style': '+', 'size': 100, 'color': 'red'}}
plot_omega_gamma(df_dict)


display(Imp_NE_top_129038)

mode_structures_of_points(filepath, criteria_list, displayed_outputs, Imp_NE_top_129038, [2,1])
# Out:
#         scanfile suffix  ky_min  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0  scanfiles0010   0001     0.3          7        0.155    4.371523
# 0  scanfiles0010   0002     0.5         12        0.247    6.966234
# 0  scanfiles0010   0003     0.7         17        0.343    9.673758
# 0  scanfiles0002   0002     1.0         24        0.498   14.045282
# 0  scanfiles0002   0001     5.0        122        1.280   36.100323
# 0  scanfiles0010   0004     5.0        122        1.278   36.043916
# 0  scanfiles0010   0005    10.0        244        0.879   24.790769
# 0  scanfiles0010   0006    50.0       1219        0.434   12.240266
#
#    omega(cs/a)  omega(kHz)  nz0  hyp_z        x0  kymin
# 0       -0.745  -21.011516  128   -6.0  0.655012    0.3
# 0       -1.168  -32.941544  128   -6.0  0.655012    0.5
# 0       -1.568  -44.222895  128   -6.0  0.655012    0.7
# 0       -2.108  -59.452719  256   -6.0  0.655012    1.0
# 0       -6.658 -187.778085  256   -6.0  0.655012    5.0
# 0       -6.658 -187.778085  128   -6.0  0.655012    5.0
# 0      -10.627 -299.717289  128   -6.0  0.655012   10.0
# 0      -20.592 -580.763942  128   -6.0  0.655012   50.0
# mode_structure_of_points:  scanfiles0010 0001
# which_scanfiles:  scanfiles0010 0001
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0001
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0001
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0001  128   -6.0  0.655012    0.3
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0010 0002
# which_scanfiles:  scanfiles0010 0002
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0002
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0002
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0002  128   -6.0  0.655012    0.5
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0010 0003
# which_scanfiles:  scanfiles0010 0003
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0003
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0003
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0003  128   -6.0  0.655012    0.7
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0002 0002
# which_scanfiles:  scanfiles0002 0002
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0002 0002
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0002
# selective scan: 0002
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0002   0002  256   -6.0  0.655012    1.0
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0002 0001
# which_scanfiles:  scanfiles0002 0001
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0002 0001
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0002
# selective scan: 0001
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0002   0001  256   -6.0  0.655012    5.0
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0010 0004
# which_scanfiles:  scanfiles0010 0004
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0004
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0004
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0004  128   -6.0  0.655012    5.0
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0010 0005
# which_scanfiles:  scanfiles0010 0005
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0005
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0005
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0005  128   -6.0  0.655012   10.0
# Calculating growth rate from phi.
# mode_structure_of_points:  scanfiles0010 0006
# which_scanfiles:  scanfiles0010 0006
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~we party here~~~~~~~~~~~~~~
# scanfiles0010 0006
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scanfile path: /global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_NE_top/scanfiles0010
# selective scan: 0006
#         scanfile suffix  nz0  hyp_z        x0  kymin
# 0  scanfiles0010   0006  128   -6.0  0.655012   50.0
# Calculating growth rate from phi.

# %%
filepath = '/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_OM_top'

criteria_list = []
displayed_outputs = ['nz0', 'x0'] 
Imp_OM_top_129038 = omega_df(filepath, criteria_list, displayed_outputs)

df_dict= {'129038 - OM': {'dict': Imp_OM_top_129038, 'marker_style': '+', 'size': 100, 'color': 'red'}}
plot_omega_gamma(df_dict)

display(Imp_OM_top_129038)

# mode_structures_of_points(filepath, criteria_list, displayed_outputs, Imp_OM_top_129038, [2,1])
# Out:
#         scanfile suffix  ky_min  n0_global  gamma(cs/a)  gamma(kHz)  \
# 0  scanfiles0008   0001     0.1          2     2.635000   41.449861
# 0  scanfiles0008   0002     0.3          7     0.548000    8.620313
# 0  scanfiles0001   0001     0.5         12     0.750567   11.806785
# 0  scanfiles0008   0003     0.5         12     0.752000   11.829334
# 0  scanfiles0009   0001     0.7         17     0.846000   13.308001
# 0  scanfiles0009   0002     0.9         22     0.852000   13.402384
# 0  scanfiles0003   0001     1.0         25     0.833000   13.103505
# 0  scanfiles0009   0003     1.0         25     0.833000   13.103505
# 0  scanfiles0009   0004     5.0        123     0.154000    2.422497
# 0  scanfiles0010   0001   100.0       2455     2.045000   32.168868
# 0  scanfiles0007   0001   200.0       4910    29.743492  467.879935
#
#    omega(cs/a)  omega(kHz)  nz0       x0
# 0    -0.919000  -14.456327  128  0.90999
# 0    -1.504000  -23.658668  128  0.90999
# 0    -1.103134  -17.352839  512  0.90999
# 0    -1.102000  -17.335008  128  0.90999
# 0    -0.746000  -11.734951  128  0.90999
# 0    -0.507000   -7.975362  128  0.90999
# 0    -0.420000   -6.606809  128  0.90999
# 0    -0.420000   -6.606809  128  0.90999
# 0    -0.133000   -2.092156  128  0.90999
# 0    -6.137000  -96.538064  128  0.90999
# 0   -20.718728 -325.915898  512  0.90999

# %%
filepath = "/global/cscratch1/sd/joeschm/ST_research/NSTXU/129038/Impurities_PE_top"

Imp_PE_top_129038 = omega_df(filepath, [], ['nz0', 'hyp_z', 'x0', 'shat'])
df_dict= {'129038 - OM': {'dict': Imp_PE_top_129038, 'marker_style': '+', 'size': 100, 'color': 'red'}}
plot_omega_gamma(df_dict)

display(Imp_PE_top_129038)

# mode_structures_of_points(filepath, criteria_list, displayed_outputs, Imp_PE_top_129038, [2,1])
# Out:
# Your dictionary labeled 129038 - OM  is empty
# Empty DataFrame
# Columns: []
# Index: []

# %%
# df_dict= {'129038 - NE': {'dict': Imp_NE_top_129038, 'marker_style': '+', 'size': 100, 'color': 'red'},
#           '129038 - OM': {'dict': Imp_OM_top_129038, 'marker_style': 'x', 'size': 100, 'color': 'blue'},
#           '129038 - PE': {'dict': Imp_PE_top_129038, 'marker_style': '.', 'size': 100, 'color': 'green'}}

# # df_dict= {'129038 - NE': {'dict': Imp_NE_top_129038, 'marker_style': '+', 'size': 100, 'color': 'red'}}


# plot_omega_gamma(df_dict)
