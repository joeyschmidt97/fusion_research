# %%
import sys
sys.path.insert(0, '/global/homes/j/joeschm/Notebooks/omega_reading')
import om_kHz_DF_V2 as om
import matplotlib.pyplot as plt

# %%
path_efit = '/global/cscratch1/sd/joeschm/162940/efit'
path_COMP_efit = '/global/cscratch1/sd/joeschm/162940/COMP_efit'
path_miller = '/global/cscratch1/sd/joeschm/162940/miller'
path_COMP_miller = '/global/cscratch1/sd/joeschm/162940/COMP_miller'

efit_omega = om.omega_df(path_efit, [], [])
COMP_efit_omega = om.omega_df(path_COMP_efit, [], [])
miller_omega = om.omega_df(path_miller, [], [])
COMP_miller_omega = om.omega_df(path_COMP_miller, [], [])

print(COMP_miller_omega)
# Out:
#         scanfile suffix  ky_min  n0_global  gamma(cs/a)   gamma(kHz)  \
# 0  scanfiles0002   0001    3.81        993    17.610000   219.481547
# 0  scanfiles0001   0001    3.81        993    17.610000   219.481547
# 0  scanfiles0000   0001    3.81        993    17.610065   219.482358
# 0  scanfiles0004   0001    3.81        993    17.624997   219.668459
# 0  scanfiles0003   0001    3.81        993    17.610065   219.482358
# 0  scanfiles0004   0002   15.23       3968    23.598033   294.113164
# 0  scanfiles0003   0002   15.23       3968    23.487968   292.741374
# 0  scanfiles0003   0003   26.36       6867    27.811570   346.628415
# 0  scanfiles0004   0003   26.36       6867    27.659227   344.729698
# 0  scanfiles0003   0004   52.73      13737   106.413259  1326.277496
# 0  scanfiles0004   0004   52.73      13737   106.325150  1325.179358
# 0  scanfiles0002   0005  121.94      31767   176.418000  2198.778853
# 0  scanfiles0004   0005  121.94      31767   175.317470  2185.062434
# ...

# %%
size = 70
marker_style = '.'

ax = efit_omega.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'red', label = 'efit', alpha = 0.5, marker = marker_style, s = size)
COMP_efit_omega.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'blue', label = 'COMP_efit',  alpha = 0.5, marker = '>', s=size, ax = ax)
miller_omega.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'green', label = 'miller',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
COMP_miller_omega.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'orange', label = 'COMP_miller',  alpha = 0.5, marker = '<', s=size, ax = ax)

plt.legend()
plt.show()


ax = efit_omega.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'red', label = 'efit', alpha = 0.5, marker = marker_style, s = size)
COMP_efit_omega.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'blue', label = 'COMP_efit',  alpha = 0.5, marker = '>', s=size, ax = ax)
miller_omega.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'green', label = 'miller',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
COMP_miller_omega.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'orange', label = 'COMP_miller',  alpha = 0.5, marker = '<', s=size, ax = ax)

plt.legend()
plt.show()
