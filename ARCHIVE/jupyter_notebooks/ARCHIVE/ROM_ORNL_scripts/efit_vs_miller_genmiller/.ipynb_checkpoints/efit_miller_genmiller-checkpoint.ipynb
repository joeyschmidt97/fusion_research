# %%
import sys
sys.path.insert(0, '/global/homes/j/joeschm/Notebooks/omega_reading')
import om_kHz_DF_V2 as om
import matplotlib.pyplot as plt

# %%
path_V2_efit = '/global/cscratch1/sd/joeschm/162940/V2_efit'
path_V2_miller = '/global/cscratch1/sd/joeschm/162940/V2_miller'

V2_efit_omega_1024 = om.omega_df(path_V2_efit, ['nz0 == 1024'], [])
V2_miller_omega_1024 = om.omega_df(path_V2_miller, ['nz0 == 1024'], [])
V2_efit_omega_512 = om.omega_df(path_V2_efit, ['nz0 == 512'], [])
V2_miller_omega_512 = om.omega_df(path_V2_miller, ['nz0 == 512'], [])
V2_efit_omega_256 = om.omega_df(path_V2_efit, ['nz0 == 256'], [])
V2_miller_omega_256 = om.omega_df(path_V2_miller, ['nz0 == 256'], [])

#print(V2_miller_omega_1024)
#print(V2_miller_omega_512)
#print(V2_miller_omega_256)

#print(V2_efit_omega_1024)
#print(V2_efit_omega_512)
#print(V2_efit_omega_256)

# %%
# size = 120
# marker_style = '.'

# ax = V2_efit_omega_512.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'red', label = 'efit (512)', alpha = 0.5, marker = '+', s = 200)
# V2_miller_omega_512.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'blue', label = 'miller (512)',  alpha = 0.5, marker = '+', s=200, ax = ax)
# V2_efit_omega_256.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'red', label = 'efit (256)',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
# V2_miller_omega_256.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'blue', label = 'miller (256)',  alpha = 0.5, marker = marker_style, s=size, ax = ax)

# plt.legend()
# plt.show()


# ax = V2_efit_omega_512.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'red', label = 'efit (512)', alpha = 0.5, marker = '+', s = 200)
# V2_miller_omega_512.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'blue', label = 'miller (512)',  alpha = 0.5, marker = '+', s=200, ax = ax)
# V2_efit_omega_256.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'red', label = 'efit (256)',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
# V2_miller_omega_256.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'blue', label = 'miller (256)',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
# plt.legend()
# plt.show()

# %%
size = 120
marker_style = '.'

ax = V2_efit_omega_512.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'red', label = 'efit (512)', alpha = 0.5, marker = marker_style, s = size)
V2_miller_omega_512.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'blue', label = 'miller (512)',  alpha = 0.5, marker = marker_style, s= size, ax = ax)
V2_efit_omega_1024.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'red', label = 'efit (1024)',  alpha = 0.5, marker = '+', s = 200, ax = ax)
V2_miller_omega_1024.plot(x ='n0_global', y='omega(kHz)', kind = 'scatter', color = 'blue', label = 'miller (1024)',  alpha = 0.5, marker = '+', s = 200, ax = ax)

plt.legend()
plt.show()


ax = V2_efit_omega_512.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'red', label = 'efit (512)', alpha = 0.5, marker = marker_style, s = size)
V2_miller_omega_512.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'blue', label = 'miller (512)',  alpha = 0.5, marker = marker_style, s=size, ax = ax)
V2_efit_omega_1024.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'red', label = 'efit (1024)',  alpha = 0.5, marker = '+', s=200, ax = ax)
V2_miller_omega_1024.plot(x ='n0_global', y='gamma(kHz)', kind = 'scatter', color = 'blue', label = 'miller (1024)',  alpha = 0.5, marker = '+', s=200, ax = ax)


plt.legend()
plt.show()
