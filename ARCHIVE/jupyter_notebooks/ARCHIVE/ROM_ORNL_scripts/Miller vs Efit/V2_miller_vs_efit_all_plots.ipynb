# %%
import sys
sys.path.insert(0, '/global/homes/j/joeschm/Notebooks/Omega_reading')
import om_kHz_DF_V2 as om

# %% [markdown]
# ## C2: EFIT vs Miller Plots (DIIID)

# %%
C2_efit_path = "/global/cscratch1/sd/joeschm/162940/COMP_efit"
C2_miller_path = "/global/cscratch1/sd/joeschm/162940/COMP_miller"

C2_efit_omega = om.omega_df(C2_efit_path, ['500 < nz0 < 600'], ['x0'])
C2_miller_omega = om.omega_df(C2_miller_path, ['500 < nz0 < 600'], ['x0'])

#print(C2_efit_omega)
#print(C2_miller_omega)

# %%
om.plot_omega_gamma(C2_efit_omega, C2_miller_omega, 'C2_efit', 'C2_miller')

# %% [markdown]
# ## C2: EFIT2 vs Miller2 Plots (AUG)

# %%
C2_efit2_path = "/global/cscratch1/sd/joeschm/AUG/COMP2_efit2"
C2_miller2_path = "/global/cscratch1/sd/joeschm/AUG/COMP2_REG_miller2"

C2_efit2_omega = om.omega_df(C2_efit2_path, ['500 < nz0 < 600'], ['x0', 'omn1', 'omt1'])
C2_miller2_omega = om.omega_df(C2_miller2_path, ['500 < nz0 < 600', 'omn1 < 80', 'omt1 < 100'], [])

#print(C2_efit2_omega)
#print(C2_miller2_omega)

# %%
om.plot_omega_gamma(C2_efit2_omega, C2_miller2_omega, 'C2_efit2', 'C2_miller2')
