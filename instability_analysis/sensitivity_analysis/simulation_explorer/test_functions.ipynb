# %%
from equidistant_sphere_points import equidst_sphr_pts, cart_to_disk, golden_ratio_eq_sphr_pts

from plotting_sphere_disk import plot_simulation_disk

# %%
r = 20
N = 500

x,y,z = golden_ratio_eq_sphr_pts(r, N)

points_dict = {'x': {'values': x, 'units':'coll'}, 
               'y': {'values': y, 'units':'beta'},
               'z': {'values': z, 'units':'omt'}}


plot_simulation_disk(points_dict, True)
