# %%
from growth_rate_df_builder import growth_freq_dataframe
import matplotlib.pyplot as plt

from src.dict_parameters_data import parameters_filepath_to_dict, create_species_tuple

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan/'

gr_sim_df = growth_freq_dataframe(filepath, ['kymin>10'])

# %%
kymin_array = gr_sim_df['kymin'].unique()

print(kymin_array)

for kymin in kymin_array:
    print(kymin)

print(32 in kymin_array)


result = gr_sim_df.loc[gr_sim_df['kymin'] == 30.0, 'directory'].iloc[0]

print(result)
# Out:
# [0.1]
# 0.1
# False
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /global/homes/j/joeschm/fusion_research/instability_analysis/basic_analysis_tools/growth_rate/test.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bperlmutter-p1.nersc.gov/global/homes/j/joeschm/fusion_research/instability_analysis/basic_analysis_tools/growth_rate/test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     print(kymin)
#       <a href='vscode-notebook-cell://ssh-remote%2Bperlmutter-p1.nersc.gov/global/homes/j/joeschm/fusion_research/instability_analysis/basic_analysis_tools/growth_rate/test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> print(32 in kymin_array)
# ...

# %%
plt.scatter(gr_sim_df['kymin'], gr_sim_df['gamma'], marker='.')
plt.xscale('log')

# %%
plt.scatter(gr_sim_df['kymin'], gr_sim_df['omega'], marker='.')
plt.xscale('log')
