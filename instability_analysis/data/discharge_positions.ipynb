# %%
from instability_analysis.src.basic_analysis_tools.discharge_info.plot_OM_NE_PE import multiplot_PE_NE_OM

from filepath_list import filepath_129038, filepath_129015

# %% [markdown]
# # 129015

# %%
profile_129015 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129015'

PE_15 = 0.870
NE_15 = 0.850
OM_15 = 0.936

points = [PE_15, NE_15, OM_15]

multiplot_PE_NE_OM(profile_129015, points)

# %% [markdown]
# # 129038

# %%
profile_129038 = '/global/homes/j/joeschm/st_research/NSTXU_discharges/129038'

PE_38 = 0.499
NE_38 = 0.655
OM_38 = 0.909

points = [PE_38, NE_38, OM_38]

multiplot_PE_NE_OM(profile_129038, points)
