# %%
from GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df

from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

import os

# %% [markdown]
# # 129015

# %%
NE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top'
PE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top'
OM_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top'

# %% [markdown]
# ### 129015 - NE

# %%
kymin_129015_NE = os.path.join(NE_129015, 'kymin_scan')
kymin_129015_NE_df = growth_freq_dataframe(kymin_129015_NE)


criteria = []

print(kymin_129015_NE)

kymin_list = list(kymin_129015_NE_df['kymin'].unique())
kymin_list.sort()
print(kymin_list)
gamma_omega_plot(kymin_129015_NE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 20.0, 30.0, 40.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0, 400.0, 600.0, 800.0]

# %%
# kx_center_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kx_center_scan'

kx_center_path = kymin_129015_NE = os.path.join(NE_129015, 'kx_center_scan')
kymin_path = os.path.join(NE_129015, 'kymin_scan')

path_list = [kymin_path, kx_center_path]
# path_list = kx_center_path
print(kx_center_path)

# criteria = ['gamma', 'omega']
# criteria = []
# # kymin_129015_NE_df = sim_filepath_to_df(path, criteria)

# kymin_129015_NE_df = sim_filepath_to_df(kx_center_path, criteria)
# kymin_129015_NE_df['theta_0'] = kymin_129015_NE_df['kx_center']/(kymin_129015_NE_df['shat']*kymin_129015_NE_df['kymin'])

# # condition = (kymin_129015_NE_df['kymin'] >= 100) & (kymin_129015_NE_df['kymin'] <= 4000)
# condition = []
 
# if condition == []:
#     kymin_df_sorted = kymin_129015_NE_df
#     # kymin_df_sorted = kymin_129015_NE_df.loc[condition]
# else:
#     # kymin_df_sorted = kymin_129015_NE_df
#     print('dsa')
#     kymin_df_sorted = kymin_129015_NE_df.loc[condition]

# kymin_list = list(kymin_df_sorted['kymin'].unique())
# kymin_list.sort()
# print(kymin_list)


# print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status']])
# print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'filepath']].apply(lambda x: '/'.join(x['filepath'].split('/')[-3:]), axis=1))




# print(kymin_129015_NE_df[['kymin', 'kx_center', 'suffix']])
gamma_omega_plot(path_list, label_key='theta_0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kx_center_scan
# [0.1, 0.5, 1.0, 3.0, 5.0, 7.0, 10.0, 30.0, 70.0, 100.0, 150.0, 200.0, 300.0]
#     kymin suffix   theta_0         status  nx0
# 0     0.1   0001       NaN      CONVERGED    5
# 1     0.1   0002  0.837758      CONVERGED    5
# 2     0.1   0003  1.675516      CONVERGED    5
# 3     0.1   0004  2.513274      CONVERGED    5
# 4     0.1   0005  3.351032      CONVERGED    5
# ..    ...    ...       ...            ...  ...
# 73  300.0   0002  3.351032      CONVERGED    5
# 74  300.0   0003  4.188790      CONVERGED    5
# 75  300.0   0001       NaN  NOT_CONVERGED    5
# 76  300.0   0002  0.837758      CONVERGED    5
# 77  300.0   0003  1.675516      CONVERGED    5
#
# [78 rows x 5 columns]
# 0     kx_center_scan/scanfiles0000/parameters_0001
# 1     kx_center_scan/scanfiles0000/parameters_0002
# 2     kx_center_scan/scanfiles0000/parameters_0003
# 3     kx_center_scan/scanfiles0000/parameters_0004
# ...

# %% [markdown]
# ### 129015 - PE

# %%
# kx_center_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kx_center_scan'

kx_center_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kx_center_small_angle_scan'

kymin_path = os.path.join(PE_129015, 'kymin_scan')

path_list = [kymin_path, kx_center_path]
# path_list = kx_center_path
print(kx_center_path)

criteria = ['gamma', 'omega']
criteria = []
# kymin_129015_NE_df = sim_filepath_to_df(path, criteria)

kymin_129015_NE_df = sim_filepath_to_df(kx_center_path, criteria)
kymin_129015_NE_df['theta_0'] = kymin_129015_NE_df['kx_center']/(kymin_129015_NE_df['shat']*kymin_129015_NE_df['kymin'])

# condition = (kymin_129015_NE_df['kymin'] >= 100) & (kymin_129015_NE_df['kymin'] <= 4000)
condition = []
 
if condition == []:
    kymin_df_sorted = kymin_129015_NE_df
    # kymin_df_sorted = kymin_129015_NE_df.loc[condition]
else:
    # kymin_df_sorted = kymin_129015_NE_df
    print('dsa')
    kymin_df_sorted = kymin_129015_NE_df.loc[condition]

kymin_list = list(kymin_df_sorted['kymin'].unique())
kymin_list.sort()
print(kymin_list)


print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'nx0']])
print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'filepath']].apply(lambda x: '/'.join(x['filepath'].split('/')[-3:]), axis=1))




# print(kymin_129015_NE_df[['kymin', 'kx_center', 'suffix']])
gamma_omega_plot(path_list, label_key='theta_0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kx_center_small_angle_scan
# [0.1, 0.3, 1.0, 2.0, 10.0, 30.0, 50.0, 100.0, 300.0]
#     kymin suffix   theta_0         status  nx0
# 0     1.0   0001  0.174533      CONVERGED    7
# 1     1.0   0002  0.087266      CONVERGED    7
# 2     1.0   0003  0.017453      CONVERGED    7
# 3     0.1   0001  0.174533      CONVERGED    7
# 4     0.1   0002  0.087266  NOT_CONVERGED    7
# 5     0.1   0003  0.017453      CONVERGED    7
# 6    30.0   0001  0.174533      CONVERGED    7
# 7    30.0   0002  0.087266      CONVERGED    7
# 8    30.0   0003  0.017453      CONVERGED    7
# 9   100.0   0001  0.174533      CONVERGED    7
# 10  100.0   0002  0.087266      CONVERGED    7
# 11  100.0   0003  0.017453      CONVERGED    7
# 12  300.0   0001  0.174533      CONVERGED    7
# 13  300.0   0002  0.087266      CONVERGED    7
# 14  300.0   0003  0.017453      CONVERGED    7
# 15    2.0   0001  0.174533      CONVERGED    7
# ...

# %%
kymin_129015_PE = os.path.join(PE_129015, 'kymin_scan')
kymin_129015_NE_df = growth_freq_dataframe(kymin_129015_NE)



criteria = []

print(kymin_129015_NE)

kymin_list = list(kymin_129015_NE_df['kymin'].unique())
kymin_list.sort()
print(kymin_list)

print(kymin_129015_PE)
gamma_omega_plot(kymin_129015_PE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 20.0, 30.0, 40.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0, 400.0, 600.0, 800.0]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan

# %% [markdown]
# ### 129015 - OM

# %%
kymin_129015_OM = os.path.join(OM_129015, 'kymin_scan')

criteria = ['kymin < 910']

kymin_df = growth_freq_dataframe(kymin_129015_OM, criteria)

OM_kymin_list = list(kymin_df['kymin'].unique())
OM_kymin_list.sort()
print(OM_kymin_list)

print(kymin_129015_OM)
gamma_omega_plot(kymin_129015_OM, criteria)
# Out:
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 270.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 850.0, 900.0]
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan

# %%
# kx_center_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kx_center_scan'

kx_center_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan'

kymin_path = os.path.join(OM_129015, 'kymin_scan')


path_list = [kymin_path, kx_center_path]
# path_list = kx_center_path
print(kx_center_path)

criteria = ['gamma', 'omega']
criteria = []
# kymin_129015_NE_df = sim_filepath_to_df(path, criteria)

kymin_129015_NE_df = sim_filepath_to_df(kx_center_path, criteria)
kymin_129015_NE_df['theta_0'] = kymin_129015_NE_df['kx_center']/(kymin_129015_NE_df['shat']*kymin_129015_NE_df['kymin'])

# condition = (kymin_129015_NE_df['kymin'] >= 100) & (kymin_129015_NE_df['kymin'] <= 4000)
condition = []
 
if condition == []:
    kymin_df_sorted = kymin_129015_NE_df
    # kymin_df_sorted = kymin_129015_NE_df.loc[condition]
else:
    # kymin_df_sorted = kymin_129015_NE_df
    print('dsa')
    kymin_df_sorted = kymin_129015_NE_df.loc[condition]

kymin_list = list(kymin_df_sorted['kymin'].unique())
kymin_list.sort()
print(OM_kymin_list)
print(kymin_list)


print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status']])
# print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'filepath']].apply(lambda x: '/'.join(x['filepath'].split('/')[-3:]), axis=1))



criteria = ['kymin < 70']

# print(kymin_129015_NE_df[['kymin', 'kx_center', 'suffix']])
gamma_omega_plot(path_list, label_key='theta_0', criteria_list=criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 270.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 850.0, 900.0]
# [0.1, 0.2, 0.3, 0.5, 1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 10.0, 20.0, 30.0, 50.0, 100.0]
#     kymin suffix   theta_0     status
# 0     0.1   0001  1.256637  CONVERGED
# 1     0.1   0002  2.513274  CONVERGED
# 2     0.1   0003  3.769911  CONVERGED
# 3    10.0   0001  1.256637  CONVERGED
# 4    10.0   0002  2.513274  CONVERGED
# 5    10.0   0003  3.769911  CONVERGED
# 6     1.0   0001  1.256637  CONVERGED
# 7     1.0   0002  2.513274  CONVERGED
# 8     1.0   0003  3.769911  CONVERGED
# 9     0.5   0001  1.256637  CONVERGED
# 10    0.5   0002  2.513274  CONVERGED
# 11    0.5   0003  3.769911  CONVERGED
# 12   30.0   0001  1.256637  CONVERGED
# 13   30.0   0002  2.513274  CONVERGED
# 14   30.0   0003  3.769911  CONVERGED
# ...

# %% [markdown]
# # 129038

# %%
PE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top'
NE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top'
OM_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top'

# %% [markdown]
# ### 129038 - PE

# %%
kymin_129038_PE = os.path.join(PE_129038, 'kymin_scan')

criteria = []

print(kymin_129038_PE)
gamma_omega_plot(kymin_129038_PE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/kymin_scan

# %% [markdown]
# ### 129038 - NE

# %%
kymin_129038_NE = os.path.join(NE_129038, 'kymin_scan')

criteria = []

print(kymin_129038_NE)
gamma_omega_plot(kymin_129038_NE, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan

# %% [markdown]
# ### 129038 - OM

# %%
kymin_129038_OM = os.path.join(OM_129038, 'kymin_scan')

criteria = []

print(kymin_129038_OM)
gamma_omega_plot(kymin_129038_OM, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan

# %%
kymin_129015_OM = os.path.join(OM_129015, 'kymin_scan')

criteria = []

print(kymin_129015_OM)
gamma_omega_plot(kymin_129015_OM, criteria)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
