# %%
from GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df

from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

import os

# %% [markdown]
# # 129015

# %%
# NE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top'
# PE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top'
OM_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top'

# %% [markdown]
# ### 129015 PE - Wide Angle Scan

# %%
kx_center_path = os.path.join(OM_129015, 'kx_center_scan')
kymin_path = os.path.join(OM_129015, 'kymin_scan')

print(kx_center_path)
print(kymin_path)

path_list = [kymin_path, kx_center_path]

gamma_omega_plot(path_list, label_key='theta_0(deg)')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan

# %% [markdown]
# ### 129015 PE - Wide Angle Scan (kymin < 70)

# %%
kx_center_path = os.path.join(OM_129015, 'kx_center_scan')
kymin_path = os.path.join(OM_129015, 'kymin_scan')

print(kx_center_path)
print(kymin_path)

path_list = [kymin_path, kx_center_path]

criteria = ['3 < kymin < 200']
# criteria = ['gamma < 15']

gamma_omega_plot(path_list, label_key='theta_0', criteria_list = criteria, verbose=False)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan

# %%
kx_center_path = os.path.join(OM_129015, 'kx_center_scan')

print(kx_center_path)

criteria = ['gamma < 50']
# criteria = []


gamma_omega_plot(kx_center_path, label_key='theta_0', criteria_list = criteria, verbose=False)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan

# %%
kx_center_path = os.path.join(OM_129015, 'kx_center_scan')
kymin_path = os.path.join(OM_129015, 'kymin_scan')


path_list = [kymin_path, kx_center_path]
# path_list = kx_center_path
print(kx_center_path)

criteria = ['gamma', 'omega']
criteria = []
# kymin_129015_NE_df = sim_filepath_to_df(path, criteria)

kymin_129015_NE_df = sim_filepath_to_df(kx_center_path, criteria)
kymin_129015_NE_df['theta_0'] = kymin_129015_NE_df['kx_center']/(kymin_129015_NE_df['shat']*kymin_129015_NE_df['kymin'])

condition = (kymin_129015_NE_df['theta_0'] >= 0.1) & (kymin_129015_NE_df['theta_0'] <= 0.3)
# condition = []



if len(condition)==0:
    kymin_df_sorted = kymin_129015_NE_df
    # kymin_df_sorted = kymin_129015_NE_df.loc[condition]
else:
    # kymin_df_sorted = kymin_129015_NE_df
    kymin_df_sorted = kymin_129015_NE_df.loc[condition]

kymin_list = list(kymin_df_sorted['kymin'].unique())
kymin_list.sort()
print(kymin_list)


print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'kx_center']])
# print(kymin_df_sorted[['kymin', 'suffix', 'theta_0', 'status', 'filepath']].apply(lambda x: '/'.join(x['filepath'].split('/')[-3:]), axis=1))


# print(kymin_129015_NE_df[['kymin', 'kx_center', 'suffix']])
# gamma_omega_plot(path_list, label_key='theta_0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan
# [0.1, 1.0, 3.0, 5.0, 10.0, 20.0, 30.0, 40.0, 50.0, 70.0, 100.0, 200.0, 300.0, 500.0, 900.0]
#      kymin suffix  theta_0         status   kx_center
# 111    3.0   0001  0.20944      CONVERGED    2.160396
# 112   20.0   0002  0.20944      CONVERGED   14.402639
# 113   50.0   0003  0.20944      CONVERGED   36.006598
# 114    1.0   0001  0.20944      CONVERGED    0.720132
# 115   10.0   0002  0.20944  NOT_CONVERGED    7.201320
# 116  100.0   0003  0.20944      CONVERGED   72.013195
# 117    0.1   0001  0.20944      CONVERGED    0.072013
# 118    5.0   0002  0.20944  NOT_CONVERGED    3.600660
# 119  200.0   0003  0.20944      CONVERGED  144.026390
# 120    3.0   0001  0.20944      CONVERGED    2.160396
# 121   20.0   0002  0.20944      CONVERGED   14.402639
# 122   50.0   0003  0.20944      CONVERGED   36.006598
# 123  300.0   0001  0.20944      CONVERGED  216.039590
# 124  500.0   0002  0.20944      CONVERGED  360.065980
# 125  900.0   0003  0.20944      CONVERGED  648.118760
# 126   30.0   0001  0.20944      CONVERGED   21.603959
# 127   40.0   0002  0.20944      CONVERGED   28.805278
# 128   70.0   0003  0.20944      CONVERGED   50.409237

# %%
import numpy as np

increments = 72/6

inc_rad = increments*(np.pi/180)


for i in range(7):

    # print(i)

    if i % 2:
        print(i)

        print('deg:', i*increments, '// rad:', i*inc_rad)
# Out:
# 1
# deg: 12.0 // rad: 0.20943951023931956
# 3
# deg: 36.0 // rad: 0.6283185307179586
# 5
# deg: 60.0 // rad: 1.0471975511965979
