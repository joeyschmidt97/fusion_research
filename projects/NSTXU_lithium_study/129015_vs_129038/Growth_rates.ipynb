# %%
import sys
sys.path.append('/global/homes/j/joeschm/fusion_research/GENE_code')

from GENE_POST_growth_rate_plots import plot_growth_rates

# %% [markdown]
# ## 129015

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 20.0, 30.0, 40.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0]
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 20.0, 30.0, 40.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0]

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 1.5, 2.0, 2.5, 3.0, 4.0, 5.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 90.0, 100.0, 130.0, 150.0]
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 1.5, 2.0, 2.5, 3.0, 4.0, 5.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 90.0, 100.0, 130.0, 150.0]

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 300.0]
# x: [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 300.0]

# %% [markdown]
# ## 129038

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/kymin_scan
# x: [0.1, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 0.9, 1.0, 1.5, 1.7, 2.0, 2.5, 3.0, 4.0, 5.0, 10.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0]
# x: [0.1, 0.3, 0.4, 0.5, 0.55, 0.6, 0.7, 0.8, 0.9, 1.0, 1.5, 1.7, 2.0, 2.5, 3.0, 4.0, 5.0, 10.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 250.0, 300.0]

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# x: [0.1, 0.3, 0.5, 0.7, 0.9, 2.0, 4.0, 5.0, 10.0, 20.0, 25.0, 30.0, 40.0, 45.0, 50.0, 55.0, 70.0, 100.0, 130.0, 150.0, 300.0]
# x: [0.1, 0.3, 0.5, 0.7, 0.9, 2.0, 4.0, 5.0, 10.0, 20.0, 25.0, 30.0, 40.0, 45.0, 50.0, 55.0, 70.0, 100.0, 130.0, 150.0, 300.0]

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan'
plot_growth_rates(filepath)
# Out:
# filepath: /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# x: [0.1, 0.3, 0.5, 0.7, 0.9, 2.0, 5.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 250.0, 300.0]
# x: [0.1, 0.3, 0.5, 0.7, 0.9, 2.0, 5.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 250.0, 300.0]
