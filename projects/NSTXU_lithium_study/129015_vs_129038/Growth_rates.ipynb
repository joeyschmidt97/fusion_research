# %%
import sys
sys.path.append('/global/homes/j/joeschm/fusion_research/GENE_code')

from GP_growth_rate import single_plot, gamma_omega_plot

# %% [markdown]
# # ~~~~~~~~~~~~~~~~~ 129015 ~~~~~~~~~~~~~~~~~~~~~

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan'
gamma_omega_plot(filepath)

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/kymin_scan'
gamma_omega_plot(filepath)

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan'
gamma_omega_plot(filepath, verbose = True)
# Out:
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 270.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 850.0, 900.0, 950.0]
#
#
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# [0.1, 0.2, 0.3, 0.5, 0.7, 0.9, 1.0, 2.0, 3.0, 7.0, 10.0, 20.0, 30.0, 50.0, 70.0, 100.0, 130.0, 150.0, 200.0, 220.0, 250.0, 270.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0, 850.0, 900.0, 950.0]

# %% [markdown]
# # ~~~~~~~~~~~~~~~~~ 129038 ~~~~~~~~~~~~~~~~~~~~~

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/kymin_scan'
gamma_omega_plot(filepath)

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan'
gamma_omega_plot(filepath)

# kymin = 1 or 2, nky = 64/32 (depends on kymin) for NL runs

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan'
gamma_omega_plot(filepath)
