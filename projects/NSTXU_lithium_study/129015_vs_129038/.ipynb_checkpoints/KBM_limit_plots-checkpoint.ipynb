# %%
import sys
sys.path.append('/global/homes/j/joeschm/fusion_research/GENE_code')

from KBM_compare import print_data_points, KBM_color_plot, ref_values
from GENE_POST_param_data import print_parameter

# %% [markdown]
# # 129015

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0002
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0004
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0003
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0001
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0000
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0002
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0004
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0003
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0001
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0000
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0002
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0004
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0003
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0001
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0000
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0005
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %% [markdown]
# # 129038

# %%
# filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit'
# KBM_color_plot(filepath)

# %%
# filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit'
# print_data_points(filepath)

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit'
KBM_color_plot(filepath, show_z_vals = True)
# Out:
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit/scanfiles0002
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit/scanfiles0003
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit/scanfiles0001
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit/X_scanfiles0000
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit/scanfiles0000

# %%
filepath = '/global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit/scanfiles0002
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit/scanfiles0003
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit/scanfiles0001
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit/X_scanfiles0000
#
# /global/cscratch1/sd/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit/scanfiles0000
