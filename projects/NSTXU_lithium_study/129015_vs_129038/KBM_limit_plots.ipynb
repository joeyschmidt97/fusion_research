# %%
import sys
sys.path.append('/global/homes/j/joeschm/fusion_research/GENE_code')

from GP_KBM_compare import print_data_points, KBM_color_plot, ref_values
from GP_param_data import print_parameter

# %% [markdown]
# # 129015

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0001
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0004
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0002
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0003
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/scanfiles0000
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0001
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0004
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0002
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0003
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/scanfiles0000
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0001
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0004
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0002
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0003
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0000
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/scanfiles0005
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/KBM_limit/X_ARCHIVE
# Neither the current directory nor any of its child directories contain a file starting with 'parameters', or all child directories start with 'X_'.

# %% [markdown]
# # 129038

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit'
KBM_color_plot(filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit/scanfiles0001
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit/X_BACKUP_scanfiles0001
#
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit/scanfiles0002
# Traceback (most recent call last):
#   File "/global/homes/j/joeschm/ifs_scripts/plot_mode_structures.py", line 236, in <module>
#     call(['calc_omega_from_field.py',suffix[1:]])
#   File "/global/common/software/nersc/pm-2022q3/sw/python/3.9-anaconda-2021.11/lib/python3.9/subprocess.py", line 349, in call
#     with Popen(*popenargs, **kwargs) as p:
#   File "/global/common/software/nersc/pm-2022q3/sw/python/3.9-anaconda-2021.11/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/global/common/software/nersc/pm-2022q3/sw/python/3.9-anaconda-2021.11/lib/python3.9/subprocess.py", line 1821, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'calc_omega_from_field.py'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_224109/2488096451.py in <module>
#       1 filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top/KBM_limit'
# ----> 2 KBM_color_plot(filepath)
#
# ~/fusion_research/GENE_code/GP_KBM_compare.py in KBM_color_plot(filepath, color_bar, show_z_vals)
#     110
#     111 def KBM_color_plot(filepath, color_bar = 'local', show_z_vals = False):
# --> 112     beta_list, density_list, KBM_limit_list = get_data_points(filepath)
#     113
#     114     beta_den_dict = {}
#
# ~/fusion_research/GENE_code/GP_KBM_compare.py in get_data_points(filepath)
#      55             parameter_directory = param_dict['filepath']
#      56             suffix = simulation_dict['suffix']
# ---> 57             diff_abs_value = get_diff_abs_value(parameter_directory, suffix)
#      58
#      59             KBM_limit_list.append(diff_abs_value)
#
# ~/fusion_research/GENE_code/GP_KBM_compare.py in get_diff_abs_value(filepath, suffix)
#      79
#      80     # Find the line that contains the "diff/abs" value
# ---> 81     diff_abs_line = [line for line in output.split('\n') if 'diff/abs' in line][0]
#      82     diff_abs_value = float(diff_abs_line.split()[-1])   # Extract the numerical value from the line
#      83
#
# IndexError: list index out of range

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/KBM_limit'
KBM_color_plot(filepath)

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/KBM_limit'
KBM_color_plot(filepath)
